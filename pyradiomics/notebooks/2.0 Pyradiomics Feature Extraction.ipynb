# %% [markdown]
# # Feature Extraction

# %% [markdown]
# **In this section we will focus on feature extraction from a single image or the batch of images. For this project our masks (ROI) are already segmented.**

# %% [markdown]
# *On average, Pyradiomics extracts ≈1500 features per image, which consist of the 16 shape descriptors and features extracted from original and derived images (LoG with 5 sigma levels, 1 level of Wavelet decomposistions yielding 8 derived images and images derived using Square, Square Root, Logarithm and Exponential filters).*
#
# Detailed description on feature classes and individual features is provided in section [Radiomic Features](https://pyradiomics.readthedocs.io/en/latest/features.html#radiomics-features-label) of the documentation.

# %% [markdown]
# This example shows how to use the radiomics package and the feature extractor.
# The feature extractor handles preprocessing, and then calls the needed featureclasses to calculate the features.

# %% [markdown]
# ### Setting up imports
#
# First, import some built-in Python modules needed to get our testing data.
# Second, import the toolbox, only the `featureextractor` is needed, this module handles the interaction with other parts of the toolbox.
#
# Here we use `SimpleITK` (referenced as `sitk`, see http://www.simpleitk.org/ for details) to load two brain images and the corresponding segmentations as label maps.

# %%
# If you edit a module file, Jupyter’s autoreload extension reloads imported modules:
# %load_ext autoreload
# %autoreload

# %matplotlib inline
import matplotlib.pyplot as plt
import six
import os  # needed navigate the system to get the input data
import SimpleITK as sitk
import logging
import csv
import collections
import radiomics
import pandas
from datetime import datetime
from radiomics import getTestCase
from radiomics import featureextractor, getFeatureClasses
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Setting up paths

# %%
# root_path points to the root of the repository. The following line gets that location if this Notebook is run
# from it's default location in \radiomics\thesis-paper\notebooks
root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
data_path = os.path.join(root_path, "data")
input_path = os.path.join(data_path, 'input-images')
log_path = os.path.join(data_path, 'logs', 'features_extraction_log.txt')

settings_path = os.path.join(root_path, "settings")
output_path = os.path.join(data_path, 'extracted-features')

inputCSV = os.path.join(settings_path, 'batch_test_cases.csv')
params = os.path.join(settings_path, 'Params.yaml')

# %% [markdown]
# ### Setting up logging

# %%
# Get the PyRadiomics logger (default log-level = INFO)
logger = radiomics.logger
logger.setLevel(logging.DEBUG)  # set level to DEBUG to include debug log messages in log file

# Write out all log entries to a file
handler = logging.FileHandler(filename=log_path, mode='w')
formatter = logging.Formatter('%(levelname)s:%(name)s: %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# %% [markdown]
# ## Single image

# %% [markdown]
# ### Setting up data

# %% [markdown]
# Test cases can be downloaded to temporary files. This is handled by the `radiomics.getTestCase()` function, which checks if the requested test case is available and if not, downloads it. It returns a tuple with the location of the image and mask of the requested test case, or (None, None) if it fails.
#
# Alternatively, if the data is available somewhere locally, this directory can be passed as a second argument to `radiomics.getTestCase()`. If that directory does not exist or does not contain the testcase, functionality reverts to default and tries to download the test data.
#
# If getting the test case fails, PyRadiomics will log an error explaining the cause.

# %%
imagepath_1, labelpath_1 = getTestCase('brain1', input_path)

if imagepath_1 is None or labelpath_1 is None:  # Something went wrong, in this case PyRadiomics will also log an error
    raise Exception('Error getting testcase!')  # Raise exception to prevent cells below from running in case of "run all"
    
image_1 = sitk.ReadImage(imagepath_1)
label_1 = sitk.ReadImage(labelpath_1)

# %% [markdown]
# ### Show the image
#
# Using `matplotlib.pyplot` (referenced as `plt`), display the images in grayscale and labels in color.

# %%
plt.figure(figsize=(20,20))
# First image
plt.subplot(2,2,1)
plt.imshow(sitk.GetArrayFromImage(image_1)[12,:,:], cmap="gray")
plt.title("Brain #1")
plt.subplot(2,2,2)
plt.imshow(sitk.GetArrayFromImage(label_1)[12,:,:])        
plt.title("Segmentation #1")

plt.show()

# %% [markdown]
# ### Instantiating the extractor

# %% [markdown]
# Now that we have our input, we need to define the parameters and instantiate the extractor.
# For this there are five possibilities:
#
# **1. Use defaults, don't define custom settings**
#
# ```
# extractor = featureextractor.RadiomicsFeatureExtractor()
# ```
#
# **2. Define parameters in a dictionary**
#
# ```
# # First define the settings
# settings = {}
# settings['binWidth'] = 20
# settings['sigma'] = [1, 2, 3]
#
# # Instantiate the extractor
# extractor = featureextractor.RadiomicsFeatureExtractor(**settings)
# ```
#
# **3. Define parameters in the constructor**
#
# ```
# extractor = featureextractor.RadiomicsFeatureExtractor(binWidth=20, sigma=[1, 2, 3])
# ```
#
# **4. Control filters and features after initialisation**
#
# ```
# extractor.enableImageTypeByName('LoG')
#
# # Disable all feature classes, save firstorder
# extractor.disableAllFeatures()
# extractor.enableFeatureClassByName('firstorder')
#
# # Specify some additional features in the GLCM feature class
# extractor.enableFeaturesByName(glcm=['Autocorrelation', 'Homogeneity1', 'SumSquares'])
# ```
#
# **5. Use a parameter file**
#
# ```
# paramsPath = os.path.join('..', 'examples', 'exampleSettings', 'Params.yaml')
# extractor = featureextractor.RadiomicsFeatureExtractor(paramsPath)
# ```

# %%
# Instantiate the extractor
if os.path.isfile(params):
    extractor = featureextractor.RadiomicsFeatureExtractor(params)
else:  # Parameter file not found, use hardcoded settings instead
    settings = {}
    settings['binWidth'] = 25
    settings['resampledPixelSpacing'] = None  # [3,3,3]
    settings['interpolator'] = sitk.sitkBSpline
    settings['enableCExtensions'] = True
    
    extractor = featureextractor.RadiomicsFeatureExtractor(**settings)

print('Extraction parameters:')
for setting in extractor.settings.keys():
    print('\t' + setting)
    
print('\nEnabled filters:')
for image_type in extractor.enabledImagetypes.keys():
    print('\t' + image_type)
    
print('\nEnabled features:')
for feature in extractor.enabledFeatures.keys():
    print('\t' + feature)
# Out:
# Extraction parameters:
# 	minimumROIDimensions
# 	minimumROISize
# 	normalize
# 	normalizeScale
# 	removeOutliers
# 	resampledPixelSpacing
# 	interpolator
# 	preCrop
# 	padDistance
# 	distances
# 	force2D
# 	force2Ddimension
# 	resegmentRange
# 	label
# 	additionalInfo
# 	binWidth
# 	weightingNorm
#
# Enabled filters:
# 	Original
#
# Enabled features:
# 	shape
# 	firstorder
# 	glcm
# 	glrlm
# 	glszm
# 	gldm

# %% [markdown]
# ### Extract features
# Now that we have our extractor set up with the correct parameters, we can start extracting features:

# %%
result = extractor.execute(image_1, label_1)

# %%
print('Result type:', type(result))  # result is returned in a Python ordered dictionary)
print('')
print('Calculated feature')
for key, value in six.iteritems(result):
    print('\t', key, ':', value)
# Out:
# Result type: <class 'collections.OrderedDict'>
#
# Calculated feature
# 	 diagnostics_Versions_PyRadiomics : v3.0.post2+g896682d
# 	 diagnostics_Versions_Numpy : 1.17.2
# 	 diagnostics_Versions_SimpleITK : 1.2.4
# 	 diagnostics_Versions_PyWavelet : 1.0.0
# 	 diagnostics_Versions_Python : 3.7.4
# 	 diagnostics_Configuration_Settings : {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25, 'weightingNorm': None}
# 	 diagnostics_Configuration_EnabledImageTypes : {'Original': {}}
# 	 diagnostics_Image-original_Hash : 5c9ce3ca174f0f8324aa4d277e0fef82dc5ac566
# 	 diagnostics_Image-original_Dimensionality : 3D
# 	 diagnostics_Image-original_Spacing : (0.7812499999999999, 0.7812499999999999, 6.499999999999998)
# 	 diagnostics_Image-original_Size : (256, 256, 25)
# 	 diagnostics_Image-original_Mean : 385.6564080810547
# 	 diagnostics_Image-original_Minimum : 0.0
# 	 diagnostics_Image-original_Maximum : 3057.0
# 	 diagnostics_Mask-original_Hash : 9dc2c3137b31fd872997d92c9a92d5178126d9d3
# 	 diagnostics_Mask-original_Spacing : (0.7812499999999999, 0.7812499999999999, 6.499999999999998)
# 	 diagnostics_Mask-original_Size : (256, 256, 25)
# 	 diagnostics_Mask-original_BoundingBox : (162, 84, 11, 47, 70, 7)
# 	 diagnostics_Mask-original_VoxelNum : 4137
# 	 diagnostics_Mask-original_VolumeNum : 2
# 	 diagnostics_Mask-original_CenterOfMassIndex : (186.98549673676578, 106.3562968334542, 14.38917089678511)
# 	 diagnostics_Mask-original_CenterOfMass : (46.47304432559825, 16.518518098863908, 15.529610829103234)
# 	 original_shape_Elongation : 0.5621171627174117
# 	 original_shape_Flatness : 0.46105975346582595
# 	 original_shape_LeastAxisLength : 28.584423185376487
# 	 original_shape_MajorAxisLength : 61.99722046980877
# 	 original_shape_Maximum2DDiameterColumn : 49.490854979101925
# 	 original_shape_Maximum2DDiameterRow : 65.88905951721043
# 	 original_shape_Maximum2DDiameterSlice : 53.59397776919529
# 	 original_shape_Maximum3DDiameter : 69.60099030590368
# 	 original_shape_MeshVolume : 16147.51180013021
# 	 original_shape_MinorAxisLength : 34.84970166685475
# 	 original_shape_Sphericity : 0.4798234536231475
# 	 original_shape_SurfaceArea : 6438.821603779402
# 	 original_shape_SurfaceVolumeRatio : 0.3987500788652454
# 	 original_shape_VoxelVolume : 16412.658691406243
# 	 original_firstorder_10Percentile : 632.0
# 	 original_firstorder_90Percentile : 1044.4
# 	 original_firstorder_Energy : 2918821481.0
# 	 original_firstorder_Entropy : 4.601935553903786
# 	 original_firstorder_InterquartileRange : 253.0
# 	 original_firstorder_Kurtosis : 2.1807729393860265
# 	 original_firstorder_Maximum : 1266.0
# 	 original_firstorder_MeanAbsoluteDeviation : 133.44726195252767
# 	 original_firstorder_Mean : 825.2354363065023
# 	 original_firstorder_Median : 812.0
# 	 original_firstorder_Minimum : 468.0
# 	 original_firstorder_Range : 798.0
# 	 original_firstorder_RobustMeanAbsoluteDeviation : 103.00138343026683
# 	 original_firstorder_RootMeanSquared : 839.9646448180755
# 	 original_firstorder_Skewness : 0.27565085908587594
# 	 original_firstorder_TotalEnergy : 11579797135.314934
# 	 original_firstorder_Uniformity : 0.045156963555862184
# 	 original_firstorder_Variance : 24527.07920837261
# 	 original_glcm_Autocorrelation : 289.5436994017259
# 	 original_glcm_JointAverage : 16.55380772442751
# 	 original_glcm_ClusterProminence : 27995.937591943148
# 	 original_glcm_ClusterShade : 19.605083427286676
# 	 original_glcm_ClusterTendency : 108.73139325453903
# 	 original_glcm_Contrast : 47.492125114429776
# 	 original_glcm_Correlation : 0.3917522006696661
# 	 original_glcm_DifferenceAverage : 5.284468789866316
# 	 original_glcm_DifferenceEntropy : 3.74406097806642
# 	 original_glcm_DifferenceVariance : 16.65563705027098
# 	 original_glcm_JointEnergy : 0.002893149242988865
# 	 original_glcm_JointEntropy : 8.799696270248813
# 	 original_glcm_Imc1 : -0.09438938808738298
# 	 original_glcm_Imc2 : 0.6942249020670357
# 	 original_glcm_Idm : 0.20022255640475703
# 	 original_glcm_Idmn : 0.961402169623227
# 	 original_glcm_Id : 0.28722572382985156
# 	 original_glcm_Idn : 0.8726052157397169
# 	 original_glcm_InverseVariance : 0.19881884197093194
# 	 original_glcm_MaximumProbability : 0.007352392266290182
# 	 original_glcm_SumEntropy : 5.354241321485615
# 	 original_glcm_SumSquares : 39.05587959224222
# 	 original_glrlm_GrayLevelNonUniformity : 175.6351923150419
# 	 original_glrlm_GrayLevelNonUniformityNormalized : 0.04514123814981055
# 	 original_glrlm_GrayLevelVariance : 39.118151021979244
# 	 original_glrlm_HighGrayLevelRunEmphasis : 281.066493908972
# 	 original_glrlm_LongRunEmphasis : 1.2268440382584342
# 	 original_glrlm_LongRunHighGrayLevelEmphasis : 341.2865790983503
# 	 original_glrlm_LongRunLowGrayLevelEmphasis : 0.010601170478748765
# 	 original_glrlm_LowGrayLevelRunEmphasis : 0.008600397891661503
# 	 original_glrlm_RunEntropy : 4.915038003159503
# 	 original_glrlm_RunLengthNonUniformity : 3500.0432315746298
# 	 original_glrlm_RunLengthNonUniformityNormalized : 0.8950494659480998
# 	 original_glrlm_RunPercentage : 0.9404064632491029
# 	 original_glrlm_RunVariance : 0.08479457789590625
# 	 original_glrlm_ShortRunEmphasis : 0.9559391731405504
# 	 original_glrlm_ShortRunHighGrayLevelEmphasis : 268.9741798411307
# 	 original_glrlm_ShortRunLowGrayLevelEmphasis : 0.008229766244155428
# 	 original_glszm_GrayLevelNonUniformity : 82.38716577540107
# 	 original_glszm_GrayLevelNonUniformityNormalized : 0.044057307901283996
# 	 original_glszm_GrayLevelVariance : 40.60313992393263
# 	 original_glszm_HighGrayLevelZoneEmphasis : 288.6235294117647
# 	 original_glszm_LargeAreaEmphasis : 13.615508021390374
# 	 original_glszm_LargeAreaHighGrayLevelEmphasis : 3514.7614973262034
# 	 original_glszm_LargeAreaLowGrayLevelEmphasis : 0.12723841553344326
# 	 original_glszm_LowGrayLevelZoneEmphasis : 0.009100942027706215
# 	 original_glszm_SizeZoneNonUniformity : 747.5967914438503
# 	 original_glszm_SizeZoneNonUniformityNormalized : 0.3997843804512568
# 	 original_glszm_SmallAreaEmphasis : 0.6564478999587141
# 	 original_glszm_SmallAreaHighGrayLevelEmphasis : 193.438051925864
# 	 original_glszm_SmallAreaLowGrayLevelEmphasis : 0.006416982055097711
# 	 original_glszm_ZoneEntropy : 6.50821498619819
# 	 original_glszm_ZonePercentage : 0.4520183708000967
# 	 original_glszm_ZoneVariance : 8.721239097486347
# 	 original_gldm_DependenceEntropy : 6.885019899269458
# 	 original_gldm_DependenceNonUniformity : 936.6601401982113
# 	 original_gldm_DependenceNonUniformityNormalized : 0.22641047623838803
# 	 original_gldm_DependenceVariance : 2.1619872286911965
# 	 original_gldm_GrayLevelNonUniformity : 186.8143582306019
# 	 original_gldm_GrayLevelVariance : 39.19271419906397
# 	 original_gldm_HighGrayLevelEmphasis : 280.4065748126662
# 	 original_gldm_LargeDependenceEmphasis : 8.661590524534686
# 	 original_gldm_LargeDependenceHighGrayLevelEmphasis : 2335.0519700265895
# 	 original_gldm_LargeDependenceLowGrayLevelEmphasis : 0.07650590736710827
# 	 original_gldm_LowGrayLevelEmphasis : 0.00860027409479837
# 	 original_gldm_SmallDependenceEmphasis : 0.37960167130711403
# 	 original_gldm_SmallDependenceHighGrayLevelEmphasis : 110.30563945728201
# 	 original_gldm_SmallDependenceLowGrayLevelEmphasis : 0.0035453562622343696

# %% [markdown]
# ## Batch of images

# %% [markdown]
# ### Setting up data

# %% [markdown]
# Read a CSV file that contains paths for the images that we need to process.
#
# *The input file for batch processing is a CSV file where the first row contains headers and each subsequent row represents one combination of an image and a segmentation and contains at least 2 elements: 1) path/to/image, 2) path/to/mask. The headers specify the column names and must be “Image” and “Mask” for image and mask location, respectively (capital sensitive). Additional columns may also be specified, all columns are copied to the output in the same order (with calculated features appended after last column).*
#
# Read more on the [documentation](https://pyradiomics.readthedocs.io/en/latest/usage.html#batch-mode)

# %%
logger.info('pyradiomics version: %s', radiomics.__version__)
logger.info('Loading CSV')
try:
    # Use pandas to read and transpose ('.T') the input data
    # The transposition is needed so that each column represents one test case. This is easier for iteration over
    # the input cases
    flists = pandas.read_csv(inputCSV).T
except Exception:
    logger.error('CSV READ FAILED', exc_info=True)
    exit(-1)

logger.info('Loading Done')
logger.info('Patients: %d', len(flists.columns))

# %%
flists
# Out:
#                                             0  \
# ID                                     brain1
# Image  ../data/input-images/brain1_image.nrrd
# Mask   ../data/input-images/brain1_label.nrrd
#
#                                             1  \
# ID                                     brain2
# Image  ../data/input-images/brain2_image.nrrd
# Mask   ../data/input-images/brain2_label.nrrd
#
#                                              2  \
# ID                                     breast1
# Image  ../data/input-images/breast1_image.nrrd
# Mask   ../data/input-images/breast1_label.nrrd
#
#                                            3  \
# ID                                     lung1
# Image  ../data/input-images/lung1_image.nrrd
# Mask   ../data/input-images/lung1_label.nrrd
#
#                                            4
# ID                                     lung2
# Image  ../data/input-images/lung2_image.nrrd
# Mask   ../data/input-images/lung2_label.nrrd

# %% [markdown]
# ### Instantiating the extractor

# %% [markdown]
# Instantiate the features extractor using the settings (Params.yaml) file, if the file doesn't exists use some other settings.

# %%
if os.path.isfile(params):
    extractor = featureextractor.RadiomicsFeatureExtractor(params)
else:  # Parameter file not found, use hardcoded settings instead
    settings = {}
    settings['binWidth'] = 25
    settings['resampledPixelSpacing'] = None  # [3,3,3]
    settings['interpolator'] = sitk.sitkBSpline
    settings['enableCExtensions'] = True

    extractor = featureextractor.RadiomicsFeatureExtractor(**settings)
    # extractor.enableInputImages(wavelet= {'level': 2})

logger.info('Enabled input images types: %s', extractor.enabledImagetypes)
logger.info('Enabled features: %s', extractor.enabledFeatures)
logger.info('Current settings: %s', extractor.settings)

# %% [markdown]
# ### Extract features
#
# For each image, extract features and store them in a CSV file.

# %%
outputFilepath = os.path.join(output_path, 'batch_' + str(datetime.now()) + '.csv')

# Instantiate a pandas data frame to hold the results of all patients
results = pandas.DataFrame()

for entry in flists:  # Loop over all columns (i.e. the test cases)
    logger.info("(%d/%d) Processing Patient (Image: %s, Mask: %s)",
                entry + 1,
                len(flists),
                flists[entry]['Image'],
                flists[entry]['Mask'])

    imageFilepath = flists[entry]['Image']
    maskFilepath = flists[entry]['Mask']
    label = flists[entry].get('Label', None)

    if str(label).isdigit():
        label = int(label)
    else:
        label = None

    if (imageFilepath is not None) and (maskFilepath is not None):
        featureVector = flists[entry]  # This is a pandas Series
        featureVector['Image'] = os.path.basename(imageFilepath)
        featureVector['Mask'] = os.path.basename(maskFilepath)

        try:
            # PyRadiomics returns the result as an ordered dictionary, which can be easily converted to a pandas Series
            # The keys in the dictionary will be used as the index (labels for the rows), with the values of the features
            # as the values in the rows.
            result = pandas.Series(extractor.execute(imageFilepath, maskFilepath, label))
            featureVector = featureVector.append(result)
        except Exception:
            logger.error('FEATURE EXTRACTION FAILED:', exc_info=True)

        # To add the calculated features for this case to our data frame, the series must have a name (which will be the
        # name of the column.
        featureVector.name = entry
        # By specifying an 'outer' join, all calculated features are added to the data frame, including those not
        # calculated for previous cases. This also ensures we don't end up with an empty frame, as for the first patient
        # it is 'joined' with the empty data frame.
        results = results.join(featureVector, how='outer')  # If feature extraction failed, results will be all NaN

logger.info('Extraction complete, writing CSV')
# .T transposes the data frame, so that each line will represent one patient, with the extracted features as columns
results.T.to_csv(outputFilepath, index=False, na_rep='NaN')
logger.info('CSV writing complete')

# %%
results
# Out:
#                                                                         0  \
# ID                                                                 brain1
# Image                                                   brain1_image.nrrd
# Mask                                                    brain1_label.nrrd
# diagnostics_Versions_PyRadiomics                      v3.0.post2+g896682d
# diagnostics_Versions_Numpy                                         1.17.2
# ...                                                                   ...
# original_gldm_LargeDependenceLowGrayLevelEmphasis     0.07650590736710827
# original_gldm_LowGrayLevelEmphasis                    0.00860027409479837
# original_gldm_SmallDependenceEmphasis                 0.37960167130711403
# original_gldm_SmallDependenceHighGrayLevelEmphasis     110.30563945728201
# original_gldm_SmallDependenceLowGrayLevelEmphasis   0.0035453562622343696
#
#                                                                        1  \
# ID                                                                brain2
# Image                                                  brain2_image.nrrd
# Mask                                                   brain2_label.nrrd
# diagnostics_Versions_PyRadiomics                     v3.0.post2+g896682d
# diagnostics_Versions_Numpy                                        1.17.2
# ...                                                                  ...
# original_gldm_LargeDependenceLowGrayLevelEmphasis    0.06477163542005925
# original_gldm_LowGrayLevelEmphasis                  0.007352909129511827
# original_gldm_SmallDependenceEmphasis                 0.3143642190135804
# original_gldm_SmallDependenceHighGrayLevelEmphasis     98.73745327196367
# original_gldm_SmallDependenceLowGrayLevelEmphasis   0.003919611286864095
#
#                                                                        2  \
# ID                                                               breast1
# Image                                                 breast1_image.nrrd
# Mask                                                  breast1_label.nrrd
# diagnostics_Versions_PyRadiomics                     v3.0.post2+g896682d
# diagnostics_Versions_Numpy                                        1.17.2
# ...                                                                  ...
# original_gldm_LargeDependenceLowGrayLevelEmphasis       27.0475912975913
# original_gldm_LowGrayLevelEmphasis                     0.518065268065268
# original_gldm_SmallDependenceEmphasis                0.03121098627290894
# original_gldm_SmallDependenceHighGrayLevelEmphasis   0.08194786618439001
# original_gldm_SmallDependenceLowGrayLevelEmphasis   0.022342990461955925
#
#                                                                        3  \
# ID                                                                 lung1
# Image                                                   lung1_image.nrrd
# Mask                                                    lung1_label.nrrd
# diagnostics_Versions_PyRadiomics                     v3.0.post2+g896682d
# diagnostics_Versions_Numpy                                        1.17.2
# ...                                                                  ...
# original_gldm_LargeDependenceLowGrayLevelEmphasis    0.07556248355632293
# original_gldm_LowGrayLevelEmphasis                  0.005605862273240823
# original_gldm_SmallDependenceEmphasis                 0.3181860034269303
# original_gldm_SmallDependenceHighGrayLevelEmphasis     84.05116858601934
# original_gldm_SmallDependenceLowGrayLevelEmphasis   0.003630174681129408
#
#                                                                         4
# ID                                                                  lung2
# Image                                                    lung2_image.nrrd
# Mask                                                     lung2_label.nrrd
# diagnostics_Versions_PyRadiomics                      v3.0.post2+g896682d
# diagnostics_Versions_Numpy                                         1.17.2
# ...                                                                   ...
# original_gldm_LargeDependenceLowGrayLevelEmphasis       0.146818467095096
# original_gldm_LowGrayLevelEmphasis                  0.0009344850373972612
# original_gldm_SmallDependenceEmphasis                 0.11508039120847749
# original_gldm_SmallDependenceHighGrayLevelEmphasis      97.93058453415173
# original_gldm_SmallDependenceLowGrayLevelEmphasis   0.0002186069898830078
#
# [125 rows x 5 columns]

# %% [markdown]
# ## Command Line Use
#
# PyRadiomics can be used directly from the commandline via the entry point pyradiomics. Depending on the input provided, PyRadiomics is run in either single-extraction or batch-extraction mode. All options available on the commandline can be listed by running:

# %%
! pyradiomics -h
# Out:
# usage: pyradiomics image|batch [mask] [Options]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --label N, -l N       (DEPRECATED) Value of label in mask to use for
#                         feature extraction.
#   --version             Print version and exit
#
# Input:
#   Input files and arguments defining the extraction:
#   - image and mask files (single mode) or CSV-file specifying them (batch mode)
#   - Parameter file (.yml/.yaml or .json)
#   - Overrides for customization type 3 ("settings")
#   - Multi-threaded batch processing
#
#   {Image,Batch}FILE     Image file (single mode) or CSV batch file (batch mode)
#   MaskFILE              Mask file identifying the ROI in the Image.
#                         Only required when in single mode, ignored otherwise.
#   --param FILE, -p FILE
#                         Parameter file containing the settings to be used in extraction
#   --setting "SETTING_NAME:VALUE", -s "SETTING_NAME:VALUE"
#                         Additional parameters which will override those in the
#                         parameter file and/or the default settings. Multiple
#                         settings possible. N.B. Only works for customization
#                         type 3 ("setting").
#   --jobs N, -j N        (Batch mode only) Specifies the number of threads to use for
#                         parallel processing. This is applied at the case level;
#                         i.e. 1 thread per case. Actual number of workers used is
#                         min(cases, jobs).
#   --validate            If specified, check if input is valid and check if file locations point to exisiting files
#
# Output:
#   Arguments controlling output redirection and the formatting of calculated results.
#
#   --out FILE, -o FILE   File to append output to.
#   --out-dir OUT_DIR, -od OUT_DIR
#                         Directory to store output. If specified in segment mode, this writes csv output for each processed case. In voxel mode, this directory is used to store the featuremaps. If not specified in voxel mode, the current working directory is used instead.
#   --mode {segment,voxel}, -m {segment,voxel}
#                         Extraction mode for PyRadiomics.
#   --skip-nans           Add this argument to skip returning features that have an
#                         invalid result (NaN)
#   --format {csv,json,txt}, -f {csv,json,txt}
#                         Format for the output.
#                         "txt" (Default): one feature per line in format "case-N_name:value"
#                         "json": Features are written in a JSON format dictionary
#                         (1 dictionary per case, 1 case per line) "{name:value}"
#                         "csv": one row of feature names, followed by one row of
#                         feature values per case.
#   --format-path {absolute,relative,basename}
#                         Controls input image and mask path formatting in the output.
#                         "absolute" (Default): Absolute file paths.
#                         "relative": File paths relative to current working directory.
#                         "basename": Only stores filename.
#   --unix-path, -up      If specified, ensures that all paths in the output
#                         use unix-style path separators ("/").
#
# Logging:
#   Controls the (amount of) logging output to the console and the (optional) log-file.
#
#   --logging-level LEVEL
#                         Set capture level for logging
#   --log-file FILE       File to append logger output to
#   --verbosity [{1,2,3,4,5}], -v [{1,2,3,4,5}]
#                         Regulate output to stderr. By default [3], level
#                         WARNING and up are printed. By specifying this
#                         argument without a value, level INFO [4] is assumed.
#                         A higher value results in more verbose output.

# %% [markdown]
# ### Single image/mask
#
# To extract features from a single image and segmentation run: `pyradiomics <path/to/image> <path/to/segmentation>
# `

# %% [markdown]
# ### Batch Mode
#
# To extract features from a batch run: `pyradiomics <path/to/input>`
#
# *The input file for batch processing is a CSV file where the first row contains headers and each subsequent row represents one combination of an image and a segmentation and contains at least 2 elements: 1) path/to/image, 2) path/to/mask. The headers specify the column names and must be “Image” and “Mask” for image and mask location, respectively (capital sensitive). Additional columns may also be specified, all columns are copied to the output in the same order (with calculated features appended after last column).*
#
# Read more on the [documentation](https://pyradiomics.readthedocs.io/en/latest/usage.html#batch-mode)

# %% [markdown]
# **Note**
# All headers should be unique and different from headers provided by PyRadiomics (`<filter>_<class>_<feature>`). In case of conflict, values are overwritten by the PyRadiomics values.
#
# **Note**
# In batch processing, it is possible to speed up the process by applying multiprocessing. This is done on the case-level (i.e. each thread processes a single case). You can enable this by adding the `--jobs` parameter, specifying how many parallel threads you want to use.

# %% [markdown]
# ### Customization
#
# Extraction can be customized by specifying a [parameter file](https://pyradiomics.readthedocs.io/en/latest/customization.html#radiomics-parameter-file-label) in the `--param` argument and/or by specifying override settings (only [type 3 customization](https://pyradiomics.readthedocs.io/en/latest/customization.html#radiomics-settings-label)) in the `--setting` argument. Multiple overrides can be used by specifying `--setting` multiple times.

# %% [markdown]
# ### Output
#
# By default, results are printed out to the console window. To store the results in a CSV-structured text file, add the `-o <PATH>` and `-f csv` arguments, where `<PATH>` specifies the filepath where the results should be stored. e.g.:
#
# `
# pyradiomics <path/to/image> <path/to/segmentation> -o results.csv -f csv
# pyradiomics <path/to/input> -o results.csv -f csv
# `

# %% [markdown]
# ### Voxel-based Radiomics
#
# To extract feature maps (“voxel-based” extraction), simply add the argument `--mode voxel`. The calculated feature maps are then stored as images (NRRD format) in the current working directory. The name convention used is `Case-<idx>_<FeatureName>.nrrd`. An alternative output directory can be provided in the `--out-dir` command line switch. The results that are printed to the console window or the out file will still contain the diagnostic information, and the value of the extracted features is set to the location where the feature maps are stored.

# %% [markdown]
# ## Pyradiomics Modifications
# We need to change some basic functionalities of the pyradiomics library in order to achieve our goals.

# %% [markdown]
# ### CLI batch mode
# First of all we need to change the way we define the input dataset. Because we don't want to work with csv files we have modified a method called _processInput, so now we can execute `pyradiomics /data/input-images` and pyradiomics will search in path `/data/input-images` for a folder named `patients`. After finding patients folder it will search recursivley for images and masks, for all the subfolders (for each patient).

# %%
! pyradiomics ../data/input-images --param ../settings/Params.yaml
# Out:
# [2020-07-08 12:53:15] W: radiomics.script: Batch brain1: Already exists, skipping this case...
# [2020-07-08 12:53:15] W: radiomics.script: Batch brain1: Already exists, skipping this case...
# [2020-07-08 12:53:28] W: radiomics.imageoperations: Could not load required package "scipy" or "trimesh", cannot implement filter LBP 3D
# [2020-07-08 12:53:40] W: radiomics.imageoperations: Could not load required package "scipy" or "trimesh", cannot implement filter LBP 3D
# [2020-07-08 12:53:41] W: radiomics.imageoperations: Could not load required package "scipy" or "trimesh", cannot implement filter LBP 3D
# [2020-07-08 12:53:42] W: radiomics.imageoperations: Could not load required package "scipy" or "trimesh", cannot implement filter LBP 3D
# [2020-07-08 12:53:43] W: radiomics.imageoperations: Could not load required package "scipy" or "trimesh", cannot implement filter LBP 3D
# Case-1_ID: lung1
# Case-1_Image: /home/manos/git/radiomics-features-extraction/data/input-images/patients/patient1/lung1_image.nrrd
# Case-1_Mask: /home/manos/git/radiomics-features-extraction/data/input-images/patients/patient1/lung1_label.nrrd
# Case-1_original_shape_VoxelVolume: 1361.1978149414062
# Case-1_original_shape_MeshVolume: 1330.976079305013
# Case-1_original_shape_SurfaceArea: 782.2414579991738
# Case-1_original_shape_SurfaceVolumeRatio: 0.5877201477637612
# Case-1_original_shape_Sphericity: 0.7480376581937057
# Case-1_original_shape_Maximum3DDiameter: 21.344946720202447
# Case-1_original_shape_Maximum2DDiameterSlice: 16.627323762644803
# Case-1_original_shape_Maximum2DDiameterColumn: 19.555665988802964
# Case-1_original_shape_Maximum2DDiameterRow: 17.557494838387395
# Case-1_original_shape_MajorAxisLength: 17.374483317150457
# Case-1_original_shape_MinorAxisLength: 12.488622781409067
# Case-1_original_shape_LeastAxisLength: 8.936318223606328
# Case-1_original_shape_Elongation: 0.7187910312752422
# Case-1_wavelet-LLH_firstorder_Mean: -78.28855078492866
# Case-1_wavelet-LLH_firstorder_Median: -194.50960946183898
# Case-1_wavelet-LLH_firstorder_Minimum: -993.7685109230184
# Case-1_wavelet-LLH_firstorder_Range: 1801.4753411564925
# Case-1_wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation: 346.7311080721299
# Case-1_wavelet-LLH_firstorder_RootMeanSquared: 484.5260519766112
# Case-1_wavelet-LLH_firstorder_Skewness: 0.28222457570312887
# Case-1_wavelet-LLH_firstorder_TotalEnergy: 319562278.8775871
# Case-1_wavelet-LLH_firstorder_Uniformity: 0.01930002612162399
# Case-1_wavelet-LLH_firstorder_Variance: 228636.39786003734
# Case-1_wavelet-LLH_glcm_Autocorrelation: 1161.679416686134
# Case-1_wavelet-LLH_glcm_JointAverage: 34.83077035600067
# Case-1_wavelet-LLH_glcm_ClusterProminence: 1205783.2340873813
# Case-1_wavelet-LLH_glcm_ClusterShade: 4992.113317570769
# Case-1_wavelet-LLH_glcm_ClusterTendency: 593.1558105387338
# Case-1_wavelet-LLH_glcm_Contrast: 810.926345164253
# Case-1_wavelet-LLH_glcm_Correlation: -0.18258923332461136
# Case-1_wavelet-LLH_glcm_DifferenceAverage: 21.023618010326093
# Case-1_wavelet-LLH_glcm_DifferenceEntropy: 4.993412971189855
# Case-1_wavelet-LLH_glcm_DifferenceVariance: 223.74191610230585
# Case-1_wavelet-LLH_glcm_JointEnergy: 0.002325449316182839
# Case-1_wavelet-LLH_glcm_JointEntropy: 9.064725203026908
# Case-1_wavelet-LLH_glcm_Imc1: -0.4231728056939462
# Case-1_wavelet-LLH_glcm_Imc2: 0.9957525580664959
# Case-1_wavelet-LLH_glcm_Idm: 0.11884229091707119
# Case-1_wavelet-LLH_glcm_Idmn: 0.8908479813194954
# Case-1_wavelet-LLH_glcm_Id: 0.17440057173427334
# Case-1_wavelet-LLH_glcm_Idn: 0.8068705746650335
# Case-1_wavelet-LLH_glcm_InverseVariance: 0.11589165422741836
# Case-1_wavelet-LLH_glcm_MaximumProbability: 0.008638406564588629
# Case-1_wavelet-LLH_glcm_SumEntropy: 5.990563493072599
# Case-1_wavelet-LLH_glcm_SumSquares: 351.0205389257468
# Case-1_wavelet-LLH_glrlm_GrayLevelNonUniformity: 15.34068420652744
# Case-1_wavelet-LLH_glrlm_GrayLevelNonUniformityNormalized: 0.01916441003468787
# Case-1_wavelet-LLH_glrlm_GrayLevelVariance: 364.0373368555362
# Case-1_wavelet-LLH_glrlm_HighGrayLevelRunEmphasis: 1767.3998468467241
# Case-1_wavelet-LLH_glrlm_LongRunEmphasis: 1.1881350843445235
# Case-1_wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis: 2075.8883159324755
# Case-1_wavelet-LLH_glrlm_LongRunLowGrayLevelEmphasis: 0.0052609579642424725
# Case-1_wavelet-LLH_glrlm_LowGrayLevelRunEmphasis: 0.0044411074962512394
# Case-1_wavelet-LLH_glrlm_RunEntropy: 6.0224359243037116
# Case-1_wavelet-LLH_glrlm_RunLengthNonUniformity: 749.2186402208343
# Case-1_wavelet-LLH_glrlm_RunLengthNonUniformityNormalized: 0.9300124448566993
# Case-1_wavelet-LLH_glrlm_RunPercentage: 0.9557945041816011
# Case-1_wavelet-LLH_glrlm_RunVariance: 0.07699858295491821
# Case-1_wavelet-LLH_glrlm_ShortRunEmphasis: 0.96963038299415
# Case-1_wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis: 1716.2996245554784
# Case-1_wavelet-LLH_glrlm_ShortRunLowGrayLevelEmphasis: 0.004289588974383392
# Case-1_wavelet-LLH_glszm_GrayLevelNonUniformity: 8.421052631578947
# Case-1_wavelet-LLH_glszm_GrayLevelNonUniformityNormalized: 0.018467220683287166
# Case-1_wavelet-LLH_glszm_GrayLevelVariance: 346.94586315020007
# Case-1_wavelet-LLH_glszm_HighGrayLevelZoneEmphasis: 1777.8092105263158
# Case-1_wavelet-LLH_glszm_LargeAreaEmphasis: 6.883771929824562
# Case-1_wavelet-LLH_glszm_LargeAreaHighGrayLevelEmphasis: 10147.42543859649
# Case-1_wavelet-LLH_glszm_LargeAreaLowGrayLevelEmphasis: 0.02748048638855924
# Case-1_wavelet-LLH_glszm_LowGrayLevelZoneEmphasis: 0.004235294185776139
# Case-1_wavelet-LLH_glszm_SizeZoneNonUniformity: 204.890350877193
# Case-1_wavelet-LLH_glszm_SizeZoneNonUniformityNormalized: 0.44932094490612495
# Case-1_wavelet-LLH_glszm_SmallAreaEmphasis: 0.6956367832880526
# Case-1_wavelet-LLH_glszm_SmallAreaHighGrayLevelEmphasis: 1191.6043454307387
# Case-1_wavelet-LLH_glszm_SmallAreaLowGrayLevelEmphasis: 0.0020561107355603347
# Case-1_wavelet-LLH_glszm_ZoneEntropy: 7.037818339696042
# Case-1_wavelet-LLH_glszm_ZonePercentage: 0.5448028673835126
# Case-1_wavelet-LLH_glszm_ZoneVariance: 3.514615073868883
# Case-1_wavelet-LLH_gldm_DependenceEntropy: 7.375938406524643
# Case-1_wavelet-LLH_gldm_DependenceNonUniformity: 239.92951015531662
# Case-1_wavelet-LLH_gldm_DependenceNonUniformityNormalized: 0.286654133996794
# Case-1_wavelet-LLH_gldm_DependenceVariance: 1.498604705603588
# Case-1_wavelet-LLH_gldm_GrayLevelNonUniformity: 16.154121863799283
# Case-1_wavelet-LLH_gldm_GrayLevelVariance: 366.1581799936908
# Case-1_wavelet-LLH_gldm_HighGrayLevelEmphasis: 1762.4348864994026
# Case-1_wavelet-LLH_gldm_LargeDependenceEmphasis: 6.118279569892473
# Case-1_wavelet-LLH_gldm_LargeDependenceHighGrayLevelEmphasis: 9632.89127837515
# Case-1_wavelet-LLH_gldm_LargeDependenceLowGrayLevelEmphasis: 0.025970652960811788
# Case-1_wavelet-LLH_gldm_LowGrayLevelEmphasis: 0.004448380303908638
# Case-1_wavelet-LLH_gldm_SmallDependenceEmphasis: 0.4604295589203423
# Case-1_wavelet-LLH_gldm_SmallDependenceHighGrayLevelEmphasis: 801.3734618630408
# Case-1_wavelet-LLH_gldm_SmallDependenceLowGrayLevelEmphasis: 0.0015673268102103237
# Case-1_wavelet-LHL_firstorder_10Percentile: -42.72351348018925
# Case-1_wavelet-LHL_firstorder_90Percentile: 11.06984070880354
# Case-1_wavelet-LHL_firstorder_Energy: 640789.3639991211
# Case-1_wavelet-LHL_firstorder_Entropy: 1.9213800774299292
# Case-1_wavelet-LHL_firstorder_InterquartileRange: 23.50278893700422
# Case-1_wavelet-LHL_firstorder_Kurtosis: 5.4132322542859965
# Case-1_wavelet-LHL_firstorder_Maximum: 72.12258716902572
# Case-1_wavelet-LHL_firstorder_MeanAbsoluteDeviation: 17.293388871625147
# Case-1_wavelet-LHL_firstorder_Mean: -13.930470011773831
# Case-1_wavelet-LHL_firstorder_Median: -10.769481869696403
# Case-1_wavelet-LHL_firstorder_Minimum: -123.09632047597891
# Case-1_wavelet-LHL_firstorder_Range: 195.21890764500463
# Case-1_wavelet-LHL_firstorder_RobustMeanAbsoluteDeviation: 10.509683922719836
# Case-1_wavelet-LHL_firstorder_RootMeanSquared: 27.6690926949273
# Case-1_wavelet-LHL_firstorder_Skewness: -0.6956920088365461
# Case-1_wavelet-LHL_firstorder_TotalEnergy: 1042104.0407566273
# Case-1_wavelet-LHL_firstorder_Uniformity: 0.3526319320438101
# Case-1_wavelet-LHL_firstorder_Variance: 571.5206958115492
# Case-1_wavelet-LHL_glcm_Autocorrelation: 24.334693165358317
# Case-1_wavelet-LHL_glcm_JointAverage: 4.908579719144783
# Case-1_wavelet-LHL_glcm_ClusterProminence: 22.038908314777533
# Case-1_wavelet-LHL_glcm_ClusterShade: -1.8468090257091585
# Case-1_wavelet-LHL_glcm_ClusterTendency: 2.0816860671706987
# Case-1_wavelet-LHL_glcm_Contrast: 1.119831708984252
# Case-1_wavelet-LHL_glcm_Correlation: 0.28505372167190884
# Case-1_wavelet-LHL_glcm_DifferenceAverage: 0.6955567573606017
# Case-1_wavelet-LHL_glcm_DifferenceEntropy: 1.5072016612315975
# Case-1_wavelet-LHL_glcm_DifferenceVariance: 0.6114277778664579
# Case-1_wavelet-LHL_glcm_JointEnergy: 0.17401269547703554
# Case-1_wavelet-LHL_glcm_JointEntropy: 3.393883416159856
# Case-1_wavelet-LHL_glcm_Imc1: -0.09258633621089431
# Case-1_wavelet-LHL_glcm_Imc2: 0.44643733476647174
# Case-1_wavelet-LHL_glcm_Idm: 0.6936835191606363
# Case-1_wavelet-LHL_glcm_Idmn: 0.9837335912417061
# Case-1_wavelet-LHL_glcm_Id: 0.7110733252954644
# Case-1_wavelet-LHL_glcm_Idn: 0.9271226404050986
# Case-1_wavelet-LHL_glcm_InverseVariance: 0.4295583719170063
# Case-1_wavelet-LHL_glcm_MaximumProbability: 0.36327257111743455
# Case-1_wavelet-LHL_glcm_SumEntropy: 2.436286939769571
# Case-1_wavelet-LHL_glcm_SumSquares: 0.8003794440387377
# Case-1_wavelet-LHL_glrlm_GrayLevelNonUniformity: 163.17759289814492
# Case-1_wavelet-LHL_glrlm_GrayLevelNonUniformityNormalized: 0.27998192054921955
# Case-1_wavelet-LHL_glrlm_GrayLevelVariance: 1.2705026338065788
# Case-1_wavelet-LHL_glrlm_HighGrayLevelRunEmphasis: 25.2900064922436
# Case-1_wavelet-LHL_glrlm_LongRunEmphasis: 4.188516693902711
# Case-1_wavelet-LHL_glrlm_LongRunHighGrayLevelEmphasis: 105.54487937683847
# Case-1_wavelet-LHL_glrlm_LongRunLowGrayLevelEmphasis: 0.19437649131248366
# Case-1_wavelet-LHL_glrlm_LowGrayLevelRunEmphasis: 0.057421306835305955
# Case-1_wavelet-LHL_glrlm_RunEntropy: 3.2948372849472713
# Case-1_wavelet-LHL_glrlm_RunLengthNonUniformity: 327.1673868217858
# Case-1_wavelet-LHL_glrlm_RunLengthNonUniformityNormalized: 0.5423423098901559
# Case-1_wavelet-LHL_glrlm_RunPercentage: 0.6851392335263302
# Case-1_wavelet-LHL_glrlm_RunVariance: 1.412327393987772
# Case-1_wavelet-LHL_glrlm_ShortRunEmphasis: 0.7520040740763
# Case-1_wavelet-LHL_glrlm_ShortRunHighGrayLevelEmphasis: 19.093783395008394
# Case-1_wavelet-LHL_glrlm_ShortRunLowGrayLevelEmphasis: 0.04600391156758817
# Case-1_wavelet-LHL_glszm_GrayLevelNonUniformity: 6.681818181818182
# Case-1_wavelet-LHL_glszm_GrayLevelNonUniformityNormalized: 0.1518595041322314
# Case-1_wavelet-LHL_glszm_GrayLevelVariance: 4.208161157024794
# Case-1_wavelet-LHL_glszm_HighGrayLevelZoneEmphasis: 26.34090909090909
# Case-1_wavelet-LHL_glszm_LargeAreaEmphasis: 4867.795454545455
# Case-1_wavelet-LHL_glszm_LargeAreaHighGrayLevelEmphasis: 122598.63636363637
# Case-1_wavelet-LHL_glszm_LargeAreaLowGrayLevelEmphasis: 196.8005475997217
# Case-1_wavelet-LHL_glszm_LowGrayLevelZoneEmphasis: 0.11749983895073181
# Case-1_wavelet-LHL_glszm_SizeZoneNonUniformity: 8.045454545454545
# Case-1_wavelet-LHL_glszm_SizeZoneNonUniformityNormalized: 0.1828512396694215
# Case-1_wavelet-LHL_glszm_SmallAreaEmphasis: 0.3223710469474599
# Case-1_wavelet-LHL_glszm_SmallAreaHighGrayLevelEmphasis: 9.03496844816779
# Case-1_wavelet-LHL_glszm_SmallAreaLowGrayLevelEmphasis: 0.03398121042383698
# Case-1_wavelet-LHL_glszm_ZoneEntropy: 4.7715983798534145
# Case-1_wavelet-LHL_glszm_ZonePercentage: 0.052568697729988054
# Case-1_wavelet-LHL_glszm_ZoneVariance: 4505.931301652893
# Case-1_wavelet-LHL_gldm_DependenceEntropy: 5.562019757500524
# Case-1_wavelet-LHL_gldm_DependenceNonUniformity: 48.354838709677416
# Case-1_wavelet-LHL_gldm_DependenceNonUniformityNormalized: 0.05777161136162177
# Case-1_wavelet-LHL_gldm_DependenceVariance: 28.4503282331933
# Case-1_wavelet-LHL_gldm_GrayLevelNonUniformity: 295.15292712066906
# Case-1_wavelet-LHL_gldm_GrayLevelVariance: 0.9612357954748213
# Case-1_wavelet-LHL_gldm_HighGrayLevelEmphasis: 25.23775388291517
# Case-1_wavelet-LHH_glcm_Id: 0.6462994694466152
# Case-1_wavelet-LHH_glcm_Idn: 0.9208658835178469
# Case-1_wavelet-LHH_glcm_InverseVariance: 0.4676483599185429
# Case-1_wavelet-LHH_glcm_MaximumProbability: 0.236251949705338
# Case-1_wavelet-LHH_glcm_SumEntropy: 2.2989757213676962
# Case-1_wavelet-LHH_glcm_SumSquares: 0.9805131265375
# Case-1_wavelet-LHH_glrlm_GrayLevelNonUniformity: 191.373853797866
# Case-1_wavelet-LHH_glrlm_GrayLevelNonUniformityNormalized: 0.30670375552964096
# Case-1_wavelet-LHH_glrlm_GrayLevelVariance: 1.2052131973823037
# Case-1_wavelet-LHH_glrlm_HighGrayLevelRunEmphasis: 20.62384996258146
# Case-1_wavelet-LHH_glrlm_LongRunEmphasis: 3.781204227239137
# Case-1_wavelet-LHH_glrlm_LongRunHighGrayLevelEmphasis: 73.76432719052828
# Case-1_wavelet-LHH_glrlm_LongRunLowGrayLevelEmphasis: 0.2326228670143617
# Case-1_wavelet-LHH_glrlm_LowGrayLevelRunEmphasis: 0.06762896282769791
# Case-1_wavelet-LHH_glrlm_RunEntropy: 3.0996509432192423
# Case-1_wavelet-LHH_glrlm_RunLengthNonUniformity: 401.04193257093334
# Case-1_wavelet-LHH_glrlm_RunLengthNonUniformityNormalized: 0.6058038892074801
# Case-1_wavelet-LHH_glrlm_RunPercentage: 0.7360536715375423
# Case-1_wavelet-LHH_glrlm_RunVariance: 1.1930569866714864
# Case-1_wavelet-LHH_glrlm_ShortRunEmphasis: 0.7830238900820969
# Case-1_wavelet-LHH_glrlm_ShortRunHighGrayLevelEmphasis: 16.387391559835432
# Case-1_wavelet-LHH_glrlm_ShortRunLowGrayLevelEmphasis: 0.05446031298017365
# Case-1_wavelet-LHH_glszm_GrayLevelNonUniformity: 7.2105263157894735
# Case-1_wavelet-LHH_glszm_GrayLevelNonUniformityNormalized: 0.18975069252077562
# Case-1_wavelet-LHH_glszm_GrayLevelVariance: 4.35180055401662
# Case-1_wavelet-LHH_glszm_HighGrayLevelZoneEmphasis: 26.789473684210527
# Case-1_wavelet-LHH_glszm_LargeAreaEmphasis: 5961.868421052632
# Case-1_wavelet-LHH_glszm_LargeAreaHighGrayLevelEmphasis: 113506.28947368421
# Case-1_wavelet-LHH_glszm_LargeAreaLowGrayLevelEmphasis: 329.5458087348
# Case-1_wavelet-LHH_glszm_LowGrayLevelZoneEmphasis: 0.09836675435281324
# Case-1_wavelet-LHH_glszm_SizeZoneNonUniformity: 5.7368421052631575
# Case-1_wavelet-LHH_glszm_SizeZoneNonUniformityNormalized: 0.15096952908587258
# Case-1_wavelet-LHH_glszm_SmallAreaEmphasis: 0.2794536228936053
# Case-1_wavelet-LHH_glszm_SmallAreaHighGrayLevelEmphasis: 9.169044571690492
# Case-1_wavelet-LHH_glszm_SmallAreaLowGrayLevelEmphasis: 0.0152918416016226
# Case-1_wavelet-LHH_glszm_ZoneEntropy: 4.681880802803394
# Case-1_wavelet-LHH_glszm_ZonePercentage: 0.04540023894862605
# Case-1_wavelet-LHH_glszm_ZoneVariance: 5476.709833795014
# Case-1_wavelet-LHH_gldm_DependenceEntropy: 5.388977636650877
# Case-1_wavelet-LHH_gldm_DependenceNonUniformity: 61.5089605734767
# Case-1_wavelet-LHH_gldm_DependenceNonUniformityNormalized: 0.07348740809256475
# Case-1_wavelet-LHH_gldm_DependenceVariance: 15.24157648996744
# Case-1_wavelet-LHH_gldm_GrayLevelNonUniformity: 286.3094384707288
# Case-1_wavelet-LHH_gldm_GrayLevelVariance: 0.9933354173536083
# Case-1_wavelet-LHH_gldm_HighGrayLevelEmphasis: 20.18757467144564
# Case-1_wavelet-LHH_gldm_LargeDependenceEmphasis: 77.0621266427718
# Case-1_wavelet-LHH_gldm_LargeDependenceHighGrayLevelEmphasis: 1437.2556750298686
# Case-1_wavelet-LHH_gldm_LargeDependenceLowGrayLevelEmphasis: 4.489959682310908
# Case-1_wavelet-LHH_gldm_LowGrayLevelEmphasis: 0.06521506091263445
# Case-1_wavelet-LHH_gldm_SmallDependenceEmphasis: 0.05019264086660805
# Case-1_wavelet-LHH_gldm_SmallDependenceHighGrayLevelEmphasis: 1.20733971642025
# Case-1_wavelet-LHH_gldm_SmallDependenceLowGrayLevelEmphasis: 0.004062892050214113
# Case-1_wavelet-HLL_firstorder_10Percentile: -58.964275467772026
# Case-1_wavelet-HLL_firstorder_90Percentile: 12.669020007498595
# Case-1_wavelet-HLL_firstorder_Energy: 1058556.6596940972
# Case-1_wavelet-HLL_firstorder_Entropy: 2.2846449625260132
# Case-1_wavelet-HLL_firstorder_InterquartileRange: 31.057078054285803
# Case-1_wavelet-HLL_firstorder_Kurtosis: 5.483195649368962
# Case-1_wavelet-HLL_firstorder_Maximum: 98.09921908379826
# Case-1_wavelet-HLL_firstorder_MeanAbsoluteDeviation: 22.83958550435422
# Case-1_wavelet-HLL_firstorder_Mean: -16.658456094661247
# Case-1_wavelet-HLL_firstorder_Median: -10.72692951094114
# Case-1_wavelet-HLL_firstorder_Minimum: -153.15655253242977
# Case-1_wavelet-HLL_firstorder_Range: 251.25577161622803
# Case-1_wavelet-HLL_firstorder_RobustMeanAbsoluteDeviation: 13.916776514173572
# Case-1_wavelet-HLL_firstorder_RootMeanSquared: 35.56266718239176
# Case-1_wavelet-HLL_firstorder_Skewness: -0.6471414312211595
# Case-1_wavelet-HLL_firstorder_TotalEnergy: 1721511.36459651
# Case-1_wavelet-HLL_firstorder_Uniformity: 0.2742099636152898
# Case-1_wavelet-HLL_firstorder_Variance: 987.1991376678078
# Case-1_wavelet-HLL_glcm_Autocorrelation: 46.32689662831688
# Case-1_wavelet-HLL_glcm_JointAverage: 6.74856649581705
# Case-1_wavelet-HLL_glcm_ClusterProminence: 108.94619826605496
# Case-1_wavelet-HLL_glcm_ClusterShade: -9.96583872996226
# Case-1_wavelet-HLL_glcm_ClusterTendency: 4.4532182115494985
# Case-1_wavelet-HLL_glcm_Contrast: 1.3263078643574484
# Case-1_wavelet-HLL_glcm_Correlation: 0.5369031739763054
# Case-1_wavelet-HLL_glcm_DifferenceAverage: 0.7615136036624223
# Case-1_wavelet-HLL_glcm_DifferenceEntropy: 1.5841415759302715
# Case-1_wavelet-HLL_glcm_DifferenceVariance: 0.7122942682172343
# Case-1_wavelet-HLL_glcm_JointEnergy: 0.11922569237853348
# Case-1_wavelet-HLL_glcm_JointEntropy: 3.940587615724255
# Case-1_wavelet-HLL_glcm_Imc1: -0.1734389533951131
# Case-1_wavelet-HLL_glcm_Imc2: 0.6926824795545574
# Case-1_wavelet-HLL_glcm_Idm: 0.6732434353949575
# Case-1_wavelet-HLL_glcm_Idmn: 0.9895729490520035
# Case-1_wavelet-HLL_glcm_Id: 0.6942347359986323
# Case-1_wavelet-HLL_glcm_Idn: 0.939921936500781
# Case-1_wavelet-HLL_glcm_InverseVariance: 0.4307768697836604
# Case-1_wavelet-HLL_glcm_MaximumProbability: 0.27989701680751095
# Case-1_wavelet-HLL_glcm_SumEntropy: 2.896200084256423
# Case-1_wavelet-HLL_glcm_SumSquares: 1.4448815189767372
# Case-1_wavelet-HLL_glrlm_GrayLevelNonUniformity: 137.48116338303595
# Case-1_wavelet-HLL_glrlm_GrayLevelNonUniformityNormalized: 0.23244593101269573
# Case-1_wavelet-HLL_glrlm_GrayLevelVariance: 2.015909417123451
# Case-1_wavelet-HLL_glrlm_HighGrayLevelRunEmphasis: 48.09913331483902
# Case-1_wavelet-HLL_glrlm_LongRunEmphasis: 3.8256550082638516
# Case-1_wavelet-HLL_glrlm_LongRunHighGrayLevelEmphasis: 182.71464781674558
# Case-1_wavelet-HLL_glrlm_LongRunLowGrayLevelEmphasis: 0.09422061987070164
# Case-1_wavelet-HLL_glrlm_LowGrayLevelRunEmphasis: 0.02849391785296226
# Case-1_wavelet-HLL_glrlm_RunEntropy: 3.5783005268322223
# Case-1_wavelet-HLL_glrlm_RunLengthNonUniformity: 339.9473809588127
# Case-1_wavelet-HLL_glrlm_RunLengthNonUniformityNormalized: 0.5524225910387858
# Case-1_wavelet-HLL_glrlm_RunPercentage: 0.700027570995313
# Case-1_wavelet-HLL_glrlm_RunVariance: 1.2394968603072782
# Case-1_wavelet-HLL_glrlm_ShortRunEmphasis: 0.7588432666892932
# Case-1_wavelet-HLL_glrlm_ShortRunHighGrayLevelEmphasis: 36.64984168613254
# Case-1_wavelet-HLL_glrlm_ShortRunLowGrayLevelEmphasis: 0.022552540512788283
# Case-1_wavelet-HLL_glszm_GrayLevelNonUniformity: 7.296296296296297
# Case-1_wavelet-HLL_glszm_GrayLevelNonUniformityNormalized: 0.13511659807956103
# Case-1_wavelet-HLL_glszm_GrayLevelVariance: 5.18792866941015
# Case-1_wavelet-HLL_glszm_HighGrayLevelZoneEmphasis: 51.629629629629626
# Case-1_wavelet-HLL_glszm_LargeAreaEmphasis: 3087.314814814815
# Case-1_wavelet-HLL_glszm_LargeAreaHighGrayLevelEmphasis: 154899.27777777778
# Case-1_wavelet-HLL_glszm_LargeAreaLowGrayLevelEmphasis: 63.57750742212392
# Case-1_wavelet-HLL_glszm_LowGrayLevelZoneEmphasis: 0.05034503118096994
# Case-1_wavelet-HLL_glszm_SizeZoneNonUniformity: 10.518518518518519
# Case-1_wavelet-HLL_glszm_SizeZoneNonUniformityNormalized: 0.19478737997256515
# Case-1_wavelet-HLL_glszm_SmallAreaEmphasis: 0.4332477454011987
# Case-1_wavelet-HLL_glszm_SmallAreaHighGrayLevelEmphasis: 23.321239407468987
# Case-1_wavelet-HLL_glszm_SmallAreaLowGrayLevelEmphasis: 0.029929096304572536
# Case-1_wavelet-HLL_glszm_ZoneEntropy: 4.896285132226415
# Case-1_wavelet-HLL_glszm_ZonePercentage: 0.06451612903225806
# Case-1_wavelet-HLL_glszm_ZoneVariance: 2847.064814814815
# Case-1_wavelet-HLL_gldm_DependenceEntropy: 5.9559987081071855
# Case-1_wavelet-HLL_gldm_DependenceNonUniformity: 49.90800477897252
# Case-1_wavelet-HLL_gldm_DependenceNonUniformityNormalized: 0.059627245853013766
# Case-1_wavelet-HLL_gldm_DependenceVariance: 24.674169139656478
# Case-1_wavelet-HLL_gldm_GrayLevelNonUniformity: 229.51373954599762
# Case-1_wavelet-HLL_gldm_GrayLevelVariance: 1.6691489346516906
# Case-1_wavelet-HLL_gldm_HighGrayLevelEmphasis: 47.93189964157706
# Case-1_wavelet-HLL_gldm_LargeDependenceEmphasis: 102.1015531660693
# Case-1_wavelet-HLL_gldm_LargeDependenceHighGrayLevelEmphasis: 4889.962962962963
# Case-1_wavelet-HLL_gldm_LargeDependenceLowGrayLevelEmphasis: 2.3006397279809394
# Case-1_wavelet-HLL_gldm_LowGrayLevelEmphasis: 0.026908426029733836
# Case-1_wavelet-HLL_gldm_SmallDependenceEmphasis: 0.0625253199786772
# Case-1_wavelet-HLL_gldm_SmallDependenceHighGrayLevelEmphasis: 3.2426796042728694
# Case-1_wavelet-HLL_gldm_SmallDependenceLowGrayLevelEmphasis: 0.0029213816072665216
# Case-1_wavelet-HLH_firstorder_10Percentile: -27.72114252078625
# Case-1_wavelet-HLH_firstorder_90Percentile: 31.0182719091929
# Case-1_wavelet-HLH_firstorder_Energy: 644935.8463942687
# Case-1_wavelet-HLH_firstorder_Entropy: 2.1450878783177583
# Case-1_wavelet-HLH_firstorder_InterquartileRange: 24.1606854552045
# Case-1_wavelet-HLH_firstorder_Kurtosis: 5.413063160851008
# Case-1_wavelet-HLH_firstorder_Maximum: 104.0702060025696
# Case-1_wavelet-HLH_firstorder_MeanAbsoluteDeviation: 18.954428388165578
# Case-1_wavelet-HLH_firstorder_Mean: 0.521212697128848
# Case-1_wavelet-HLH_firstorder_Median: -0.5453944168235915
# Case-1_wavelet-HLH_firstorder_Minimum: -104.62043214568445
# Case-1_wavelet-HLH_firstorder_Range: 208.69063814825404
# Case-1_wavelet-HLH_firstorder_RobustMeanAbsoluteDeviation: 10.49660606346757
# Case-1_wavelet-HLH_firstorder_RootMeanSquared: 27.758470273354202
# Case-1_wavelet-HLH_firstorder_Skewness: 0.12721387175497137
# Case-1_wavelet-HLH_firstorder_TotalEnergy: 1048847.3893539605
# Case-1_wavelet-HLH_firstorder_Uniformity: 0.2951272465667194
# Case-1_wavelet-HLH_firstorder_Variance: 770.2610092410407
# Case-1_wavelet-HLH_glcm_Autocorrelation: 30.793987883184325
# Case-1_wavelet-HLH_glcm_JointAverage: 5.556616754456987
# Case-1_wavelet-HLH_glcm_ClusterProminence: 38.55746311513535
# Case-1_wavelet-HLH_glcm_ClusterShade: 0.25785159171035177
# Case-1_wavelet-HLH_glcm_ClusterTendency: 2.5235340592425293
# Case-1_wavelet-HLH_glcm_Contrast: 2.8561423102269305
# Case-1_wavelet-HLH_glcm_Correlation: -0.06023036403141498
# Case-1_wavelet-HLH_glcm_DifferenceAverage: 1.1040133069022213
# Case-1_wavelet-HLH_glcm_DifferenceEntropy: 1.9343703294271544
# Case-1_wavelet-HLH_glcm_DifferenceVariance: 1.5263554620902415
# Case-1_wavelet-HLH_glcm_JointEnergy: 0.11099737475186625
# Case-1_wavelet-HLH_glcm_JointEntropy: 3.9802603628150695
# Case-1_wavelet-HLH_glcm_Imc1: -0.1330165310734189
# Case-1_wavelet-HLH_glcm_Imc2: 0.6136696591291101
# Case-1_wavelet-HLH_glcm_Idm: 0.5954705632855372
# Case-1_wavelet-HLH_glcm_Idmn: 0.9751558563500217
# Case-1_wavelet-HLH_glcm_Id: 0.6279120237342017
# Case-1_wavelet-HLH_glcm_Idn: 0.9108848146444621
# Case-1_wavelet-HLH_glcm_InverseVariance: 0.4375620816088013
# Case-1_wavelet-HLH_glcm_MaximumProbability: 0.19013747168484768
# Case-1_wavelet-HLH_glcm_SumEntropy: 2.5247618879741713
# Case-1_wavelet-HLH_glcm_SumSquares: 1.344919092367365
# Case-1_wavelet-HLH_glrlm_GrayLevelNonUniformity: 166.21049770918282
# Case-1_wavelet-HLH_glrlm_GrayLevelNonUniformityNormalized: 0.2625767420505189
# Case-1_wavelet-HLH_glrlm_GrayLevelVariance: 1.6040786332459427
# Case-1_wavelet-HLH_glrlm_HighGrayLevelRunEmphasis: 32.21215094964588
# Case-1_wavelet-HLH_glrlm_LongRunEmphasis: 3.0725837814298513
# Case-1_wavelet-HLH_glrlm_LongRunHighGrayLevelEmphasis: 95.25345595632507
# Case-1_wavelet-HLH_glrlm_LongRunLowGrayLevelEmphasis: 0.11896881845840775
# Case-1_wavelet-HLH_glrlm_LowGrayLevelRunEmphasis: 0.0422235083941139
# Case-1_wavelet-HLH_glrlm_RunEntropy: 3.292872301579915
# Case-1_wavelet-HLH_glrlm_RunLengthNonUniformity: 407.9441946754724
# Case-1_wavelet-HLH_glrlm_RunLengthNonUniformityNormalized: 0.6181308762766553
# Case-1_wavelet-HLH_glrlm_RunPercentage: 0.7485525227460712
# Case-1_wavelet-HLH_glrlm_RunVariance: 0.8559066718891734
# Case-1_wavelet-HLH_glrlm_ShortRunEmphasis: 0.7998785630394217
# Case-1_wavelet-HLH_glrlm_ShortRunHighGrayLevelEmphasis: 25.964057879878137
# Case-1_wavelet-HLH_glrlm_ShortRunLowGrayLevelEmphasis: 0.03484355816135191
# Case-1_wavelet-HLH_glszm_GrayLevelNonUniformity: 8.471698113207546
# Case-1_wavelet-HHL_firstorder_Mean: 0.22696145280115687
# Case-1_wavelet-HHL_firstorder_Median: 0.08063884375027242
# Case-1_wavelet-HHL_firstorder_Minimum: -10.914574313767504
# Case-1_wavelet-HHL_firstorder_Range: 22.816989458387624
# Case-1_wavelet-HHL_firstorder_RobustMeanAbsoluteDeviation: 1.3964366033370719
# Case-1_wavelet-HHL_firstorder_RootMeanSquared: 2.9749691437368115
# Case-1_wavelet-HHL_firstorder_Skewness: 0.2315782065321621
# Case-1_wavelet-HHL_firstorder_TotalEnergy: 12047.20150336752
# Case-1_wavelet-HHL_firstorder_Uniformity: 0.500314744157963
# Case-1_wavelet-HHL_firstorder_Variance: 8.798929905128526
# Case-1_wavelet-HHL_glcm_Autocorrelation: 2.3221504880568586
# Case-1_wavelet-HHL_glcm_JointAverage: 1.5116877381770417
# Case-1_wavelet-HHL_glcm_ClusterProminence: 0.57384663774348
# Case-1_wavelet-HHL_glcm_ClusterShade: -0.01692413048447439
# Case-1_wavelet-HHL_glcm_ClusterTendency: 0.573573544713052
# Case-1_wavelet-HHL_glcm_Contrast: 0.42582545294853424
# Case-1_wavelet-HHL_glcm_Correlation: 0.14783919511513893
# Case-1_wavelet-HHL_glcm_DifferenceAverage: 0.42582545294853424
# Case-1_wavelet-HHL_glcm_DifferenceEntropy: 0.9761326181319923
# Case-1_wavelet-HHL_glcm_DifferenceVariance: 0.24182567660420345
# Case-1_wavelet-HHL_glcm_JointEnergy: 0.2584748245650034
# Case-1_wavelet-HHL_glcm_JointEntropy: 1.9753741610202917
# Case-1_wavelet-HHL_glcm_Imc1: -0.023769092554090456
# Case-1_wavelet-HHL_glcm_Imc2: 0.18404389179920316
# Case-1_wavelet-HHL_glcm_Idm: 0.7870872735257328
# Case-1_wavelet-HHL_glcm_Idmn: 0.9148349094102931
# Case-1_wavelet-HHL_glcm_Id: 0.7870872735257328
# Case-1_wavelet-HHL_glcm_Idn: 0.8580581823504885
# Case-1_wavelet-HHL_glcm_InverseVariance: 0.42582545294853424
# Case-1_wavelet-HHL_glcm_MaximumProbability: 0.2998910831313462
# Case-1_wavelet-HHL_glcm_SumEntropy: 1.5495487080717576
# Case-1_wavelet-HHL_glcm_SumSquares: 0.24984974941539656
# Case-1_wavelet-HHL_glrlm_GrayLevelNonUniformity: 261.89795368464223
# Case-1_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized: 0.5001776800758775
# Case-1_wavelet-HHL_glrlm_GrayLevelVariance: 0.2499111599620612
# Case-1_wavelet-HHL_glrlm_HighGrayLevelRunEmphasis: 2.525242809487147
# Case-1_wavelet-HHL_glrlm_LongRunEmphasis: 4.010512303040975
# Case-1_wavelet-HHL_glrlm_LongRunHighGrayLevelEmphasis: 10.313201688119978
# Case-1_wavelet-HHL_glrlm_LongRunLowGrayLevelEmphasis: 2.4348399567712247
# Case-1_wavelet-HHL_glrlm_LowGrayLevelRunEmphasis: 0.6186892976282132
# Case-1_wavelet-HHL_glrlm_RunEntropy: 2.4727697450562354
# Case-1_wavelet-HHL_glrlm_RunLengthNonUniformity: 244.30178530363676
# Case-1_wavelet-HHL_glrlm_RunLengthNonUniformityNormalized: 0.4423292236112156
# Case-1_wavelet-HHL_glrlm_RunPercentage: 0.6255858836503998
# Case-1_wavelet-HHL_glrlm_RunVariance: 0.9566233548264206
# Case-1_wavelet-HHL_glrlm_ShortRunEmphasis: 0.652993343711629
# Case-1_wavelet-HHL_glrlm_ShortRunHighGrayLevelEmphasis: 1.6449674257309408
# Case-1_wavelet-HHL_glrlm_ShortRunLowGrayLevelEmphasis: 0.40499982320680117
# Case-1_wavelet-HHL_glszm_GrayLevelNonUniformity: 3.4
# Case-1_wavelet-HHL_glszm_GrayLevelNonUniformityNormalized: 0.68
# Case-1_wavelet-HHL_glszm_GrayLevelVariance: 0.16000000000000003
# Case-1_wavelet-HHL_glszm_HighGrayLevelZoneEmphasis: 3.4
# Case-1_wavelet-HHL_glszm_LargeAreaEmphasis: 68083.0
# Case-1_wavelet-HHL_glszm_LargeAreaHighGrayLevelEmphasis: 172453.6
# Case-1_wavelet-HHL_glszm_LargeAreaLowGrayLevelEmphasis: 41990.35
# Case-1_wavelet-HHL_glszm_LowGrayLevelZoneEmphasis: 0.4
# Case-1_wavelet-HHL_glszm_SizeZoneNonUniformity: 1.0
# Case-1_wavelet-HHL_glszm_SizeZoneNonUniformityNormalized: 0.2
# Case-1_wavelet-HHL_glszm_SmallAreaEmphasis: 0.07630620649526948
# Case-1_wavelet-HHL_glszm_SmallAreaHighGrayLevelEmphasis: 0.30522122159814824
# Case-1_wavelet-HHL_glszm_SmallAreaLowGrayLevelEmphasis: 0.019077452719549776
# Case-1_wavelet-HHL_glszm_ZoneEntropy: 2.321928094887361
# Case-1_wavelet-HHL_glszm_ZonePercentage: 0.005973715651135006
# Case-1_wavelet-HHL_glszm_ZoneVariance: 40060.240000000005
# Case-1_wavelet-HHL_gldm_DependenceEntropy: 4.880051257349878
# Case-1_wavelet-HHL_gldm_DependenceNonUniformity: 65.8363201911589
# Case-1_wavelet-HHL_gldm_DependenceNonUniformityNormalized: 0.07865749126781231
# Case-1_wavelet-HHL_gldm_DependenceVariance: 13.812566642257938
# Case-1_wavelet-HHL_gldm_GrayLevelNonUniformity: 418.76344086021504
# Case-1_wavelet-HHL_gldm_GrayLevelVariance: 0.2498426279210185
# Case-1_wavelet-HHL_gldm_HighGrayLevelEmphasis: 2.5376344086021505
# Case-1_wavelet-HHL_gldm_LargeDependenceEmphasis: 129.04778972520907
# Case-1_wavelet-HHL_gldm_LargeDependenceHighGrayLevelEmphasis: 330.06929510155317
# Case-1_wavelet-HHL_gldm_LargeDependenceLowGrayLevelEmphasis: 78.79241338112305
# Case-1_wavelet-HHL_gldm_LowGrayLevelEmphasis: 0.6155913978494624
# Case-1_wavelet-HHL_gldm_SmallDependenceEmphasis: 0.014868596146786959
# Case-1_wavelet-HHL_gldm_SmallDependenceHighGrayLevelEmphasis: 0.03795672909241799
# Case-1_wavelet-HHL_gldm_SmallDependenceLowGrayLevelEmphasis: 0.009096562910379198
# Case-1_wavelet-LLL_glcm_Idn: 0.8646504909072673
# Case-1_wavelet-LLL_glcm_InverseVariance: 0.09072373492844234
# Case-1_wavelet-LLL_glcm_MaximumProbability: 0.012402897491339087
# Case-1_wavelet-LLL_glcm_SumEntropy: 6.423524445034189
# Case-1_wavelet-LLL_glcm_SumSquares: 252.49309973984566
# Case-1_wavelet-LLL_glrlm_GrayLevelNonUniformity: 14.978641646343771
# Case-1_wavelet-LLL_glrlm_GrayLevelNonUniformityNormalized: 0.01847134920893256
# Case-1_wavelet-LLL_glrlm_GrayLevelVariance: 282.1727726784123
# ...
# Case-5_logarithm_firstorder_Energy: 26957716641.68431
# Case-5_logarithm_firstorder_Entropy: 3.5226761892741587
# Case-5_logarithm_firstorder_InterquartileRange: 118.10464773381318
# Case-5_logarithm_firstorder_Kurtosis: 2.1355473535757095
# Case-5_logarithm_firstorder_Maximum: 2721.3766315411453
# Case-5_logarithm_firstorder_MeanAbsoluteDeviation: 61.91858401569953
# Case-5_logarithm_firstorder_Mean: 2551.6647537238246
# Case-5_logarithm_firstorder_Median: 2552.375948838979
# Case-5_logarithm_firstorder_Minimum: 2342.826524508029
# Case-5_logarithm_firstorder_Range: 378.55010703311655
# Case-5_logarithm_firstorder_RobustMeanAbsoluteDeviation: 47.989165555889976
# Case-5_logarithm_firstorder_RootMeanSquared: 2552.6941997559766
# Case-5_logarithm_firstorder_Skewness: -0.03931071584786231
# Case-5_logarithm_firstorder_TotalEnergy: 106948949078.9477
# Case-5_logarithm_firstorder_Uniformity: 0.09435727703949728
# Case-5_logarithm_firstorder_Variance: 5254.662071336172
# Case-5_logarithm_glcm_Autocorrelation: 104.32093801087807
# Case-5_logarithm_glcm_JointAverage: 10.046914228857245
# Case-5_logarithm_glcm_ClusterProminence: 1322.1774267509686
# Case-5_logarithm_glcm_ClusterShade: -27.765049860904313
# Case-5_logarithm_glcm_ClusterTendency: 23.056369312962993
# Case-5_logarithm_glcm_Contrast: 9.71164612612262
# Case-5_logarithm_glcm_Correlation: 0.40304845964212765
# Case-5_logarithm_glcm_DifferenceAverage: 2.3799501017583684
# Case-5_logarithm_glcm_DifferenceEntropy: 2.7021714145565316
# Case-5_logarithm_glcm_DifferenceVariance: 3.4806839212463747
# Case-5_logarithm_glcm_JointEnergy: 0.012549641778032418
# Case-5_logarithm_glcm_JointEntropy: 6.664684850899342
# Case-5_logarithm_glcm_Imc1: -0.09217210482367008
# Case-5_logarithm_glcm_Imc2: 0.5660283600301781
# Case-5_logarithm_glcm_Idm: 0.3554344797913537
# Case-5_logarithm_glcm_Idmn: 0.9658948321575802
# Case-5_logarithm_glcm_Id: 0.43236814874475515
# Case-5_logarithm_glcm_Idn: 0.8802440796400813
# Case-5_logarithm_glcm_InverseVariance: 0.33226458694291455
# Case-5_logarithm_glcm_MaximumProbability: 0.024668305444041437
# Case-5_logarithm_glcm_SumEntropy: 4.236080038752006
# Case-5_logarithm_glcm_SumSquares: 8.192003859771402
# Case-5_logarithm_glrlm_GrayLevelNonUniformity: 342.3467765638354
# Case-5_logarithm_glrlm_GrayLevelNonUniformityNormalized: 0.0941585505345254
# Case-5_logarithm_glrlm_GrayLevelVariance: 8.477303493442877
# Case-5_logarithm_glrlm_HighGrayLevelRunEmphasis: 98.98027338032342
# Case-5_logarithm_glrlm_LongRunEmphasis: 1.6166075994784233
# Case-5_logarithm_glrlm_LongRunHighGrayLevelEmphasis: 165.51774202529228
# Case-5_logarithm_glrlm_LongRunLowGrayLevelEmphasis: 0.025805752065591842
# Case-5_logarithm_glrlm_LowGrayLevelRunEmphasis: 0.016805459722032953
# Case-5_logarithm_glrlm_RunEntropy: 4.083986804039204
# Case-5_logarithm_glrlm_RunLengthNonUniformity: 2991.461185186115
# Case-5_logarithm_glrlm_RunLengthNonUniformityNormalized: 0.8062918726362829
# Case-5_logarithm_glrlm_RunPercentage: 0.8791580669753258
# Case-5_logarithm_glrlm_RunVariance: 0.25777288968758133
# Case-5_logarithm_glrlm_ShortRunEmphasis: 0.9111862004431435
# Case-5_logarithm_glrlm_ShortRunHighGrayLevelEmphasis: 89.51470013638351
# Case-5_logarithm_glrlm_ShortRunLowGrayLevelEmphasis: 0.015512080479221448
# Case-5_logarithm_glszm_GrayLevelNonUniformity: 79.32629107981221
# Case-5_logarithm_glszm_GrayLevelNonUniformityNormalized: 0.09310597544578897
# Case-5_logarithm_glszm_GrayLevelVariance: 9.136892757168992
# Case-5_logarithm_glszm_HighGrayLevelZoneEmphasis: 88.85328638497653
# Case-5_logarithm_glszm_LargeAreaEmphasis: 233.96596244131456
# Case-5_logarithm_glszm_LargeAreaHighGrayLevelEmphasis: 30955.286384976527
# Case-5_logarithm_glszm_LargeAreaLowGrayLevelEmphasis: 2.362893518188557
# Case-5_logarithm_glszm_LowGrayLevelZoneEmphasis: 0.021928804144106206
# Case-5_logarithm_glszm_SizeZoneNonUniformity: 226.2511737089202
# Case-5_logarithm_glszm_SizeZoneNonUniformityNormalized: 0.2655530207851176
# Case-5_logarithm_glszm_SmallAreaEmphasis: 0.5249312554182393
# Case-5_logarithm_glszm_SmallAreaHighGrayLevelEmphasis: 44.778375763322614
# Case-5_logarithm_glszm_SmallAreaLowGrayLevelEmphasis: 0.01347260601147496
# Case-5_logarithm_glszm_ZoneEntropy: 6.093766866710167
# Case-5_logarithm_glszm_ZonePercentage: 0.20594633792603337
# Case-5_logarithm_glszm_ZoneVariance: 210.38878281425644
# Case-5_logarithm_gldm_DependenceEntropy: 6.532217713492725
# Case-5_logarithm_gldm_DependenceNonUniformity: 559.4201111916848
# Case-5_logarithm_gldm_DependenceNonUniformityNormalized: 0.13522361885223225
# Case-5_logarithm_gldm_DependenceVariance: 5.793500221942814
# Case-5_logarithm_gldm_GrayLevelNonUniformity: 390.35605511240027
# Case-5_logarithm_gldm_GrayLevelVariance: 8.487273652364225
# Case-5_logarithm_gldm_HighGrayLevelEmphasis: 100.0763838530336
# Case-5_logarithm_gldm_LargeDependenceEmphasis: 22.948755136572395
# Case-5_logarithm_gldm_LargeDependenceHighGrayLevelEmphasis: 2577.53251148175
# Case-5_logarithm_gldm_LargeDependenceLowGrayLevelEmphasis: 0.31492013772308314
# Case-5_logarithm_gldm_LowGrayLevelEmphasis: 0.016503171585863074
# Case-5_logarithm_gldm_SmallDependenceEmphasis: 0.18224778830720165
# Case-5_logarithm_gldm_SmallDependenceHighGrayLevelEmphasis: 16.4596889970799
# Case-5_logarithm_gldm_SmallDependenceLowGrayLevelEmphasis: 0.003967629136959901
# Case-5_exponential_firstorder_10Percentile: 5.2546671735919315
# Case-5_exponential_firstorder_90Percentile: 15.51401211956517
# Case-5_exponential_firstorder_Energy: 445345.4212970942
# Case-5_exponential_firstorder_Entropy: 0.022376146900310204
# Case-5_exponential_firstorder_InterquartileRange: 5.845590684125028
# Case-5_exponential_firstorder_Kurtosis: 3.6759381268596623
# Case-5_exponential_firstorder_Maximum: 27.756879058504506
# Case-5_exponential_firstorder_MeanAbsoluteDeviation: 3.3626697594285146
# Case-5_exponential_firstorder_Mean: 9.516588663207067
# Case-5_exponential_firstorder_Median: 8.42876191869269
# Case-5_exponential_firstorder_Minimum: 3.4163966781088546
# Case-5_exponential_firstorder_Range: 24.340482380395652
# Case-5_exponential_firstorder_RobustMeanAbsoluteDeviation: 2.439550457125456
# Case-5_exponential_firstorder_RootMeanSquared: 10.375421176374635
# Case-5_exponential_firstorder_Skewness: 1.0255378155159107
# Case-5_exponential_firstorder_TotalEnergy: 1766812.2793158633
# Case-5_exponential_firstorder_Uniformity: 0.9956584865387317
# Case-5_exponential_firstorder_Variance: 17.083904802481904
# Case-5_exponential_glcm_Autocorrelation: 1.0055128944976757
# Case-5_exponential_glcm_JointAverage: 1.002736344210397
# Case-5_exponential_glcm_ClusterProminence: 0.005911192312797672
# Case-5_exponential_glcm_ClusterShade: 0.005622483902346108
# Case-5_exponential_glcm_ClusterTendency: 0.005522886685580824
# Case-5_exponential_glcm_Contrast: 0.005392276267028786
# Case-5_exponential_glcm_Correlation: 0.014390399267196681
# Case-5_exponential_glcm_DifferenceAverage: 0.005392276267028786
# Case-5_exponential_glcm_DifferenceEntropy: 0.048329204805612216
# Case-5_exponential_glcm_DifferenceVariance: 0.005362777361345855
# Case-5_exponential_glcm_JointEnergy: 0.9891796411623492
# Case-5_exponential_glcm_JointEntropy: 0.05425774012744096
# Case-5_exponential_glcm_Imc1: -0.007588962349840966
# Case-5_exponential_glcm_Imc2: 0.01133618824166552
# Case-5_exponential_glcm_Idm: 0.9973038618664856
# Case-5_exponential_glcm_Idmn: 0.9989215447465942
# Case-5_exponential_glcm_Id: 0.9973038618664856
# Case-5_exponential_glcm_Idn: 0.9982025745776573
# Case-5_exponential_glcm_InverseVariance: 0.005392276267028786
# Case-5_exponential_glcm_MaximumProbability: 0.9945675176560889
# Case-5_exponential_glcm_SumEntropy: 0.04886546386041249
# Case-5_exponential_glcm_SumSquares: 0.0027287907381524025
# Case-5_exponential_glrlm_GrayLevelNonUniformity: 1527.1952551261818
# Case-5_exponential_glrlm_GrayLevelNonUniformityNormalized: 0.9778745060158827
# Case-5_exponential_glrlm_GrayLevelVariance: 0.01106274699205869
# Case-5_exponential_glrlm_HighGrayLevelRunEmphasis: 1.0339391385971655
# Case-5_exponential_glrlm_LongRunEmphasis: 81.04598636957566
# Case-5_exponential_glrlm_LongRunHighGrayLevelEmphasis: 81.08463909246089
# Case-5_exponential_glrlm_LongRunLowGrayLevelEmphasis: 81.03632318885435
# Case-5_exponential_glrlm_LowGrayLevelRunEmphasis: 0.9915152153507087
# Case-5_exponential_glrlm_RunEntropy: 2.732530669394932
# Case-5_exponential_glrlm_RunLengthNonUniformity: 471.769478200874
# Case-5_exponential_glrlm_RunLengthNonUniformityNormalized: 0.23796384729997286
# Case-5_exponential_glrlm_RunPercentage: 0.37338465257246983
# Case-5_exponential_glrlm_RunVariance: 21.1572664575591
# Case-5_exponential_glrlm_ShortRunEmphasis: 0.39298510206318255
# Case-5_exponential_glrlm_ShortRunHighGrayLevelEmphasis: 0.42574584458833503
# Case-5_exponential_glrlm_ShortRunLowGrayLevelEmphasis: 0.38479491643189456
# Case-5_exponential_glszm_GrayLevelNonUniformity: 5.888888888888889
# Case-5_exponential_glszm_GrayLevelNonUniformityNormalized: 0.654320987654321
# Case-5_exponential_glszm_GrayLevelVariance: 0.1728395061728395
# Case-5_exponential_glszm_HighGrayLevelZoneEmphasis: 3.3333333333333335
# Case-5_exponential_glszm_LargeAreaEmphasis: 1415201.6666666667
# Case-5_exponential_glszm_LargeAreaHighGrayLevelEmphasis: 1415206.6666666667
# Case-5_exponential_glszm_LargeAreaLowGrayLevelEmphasis: 1415200.4166666667
# Case-5_exponential_glszm_LowGrayLevelZoneEmphasis: 0.4166666666666667
# Case-5_exponential_glszm_SizeZoneNonUniformity: 4.333333333333333
# Case-5_exponential_glszm_SizeZoneNonUniformityNormalized: 0.48148148148148145
# Case-5_exponential_glszm_SmallAreaEmphasis: 0.6790126513239751
# Case-5_exponential_glszm_SmallAreaHighGrayLevelEmphasis: 2.716049688361012
# Case-5_exponential_glszm_SmallAreaLowGrayLevelEmphasis: 0.1697533920647159
# Case-5_exponential_glszm_ZoneEntropy: 1.446616667628207
# Case-5_exponential_glszm_ZonePercentage: 0.002175489485134155
# Case-5_exponential_glszm_ZoneVariance: 1203908.2222222222
# Case-5_exponential_gldm_DependenceEntropy: 3.591891027249014
# Case-5_exponential_gldm_DependenceNonUniformity: 625.2557408750303
# Case-5_exponential_gldm_DependenceNonUniformityNormalized: 0.15113747664371047
# Case-5_exponential_gldm_DependenceVariance: 35.611134920956275
# Case-5_exponential_gldm_GrayLevelNonUniformity: 4119.039158810732
# Case-5_exponential_gldm_GrayLevelVariance: 0.002170756730634226
# Case-5_exponential_gldm_HighGrayLevelEmphasis: 1.0065264684554025
# Case-5_exponential_gldm_LargeDependenceEmphasis: 334.6243654822335
# Case-5_exponential_gldm_LargeDependenceHighGrayLevelEmphasis: 334.64104423495286
# Case-5_exponential_gldm_LargeDependenceLowGrayLevelEmphasis: 334.62019579405364
# Case-5_exponential_gldm_LowGrayLevelEmphasis: 0.9983683828861494
# Case-5_exponential_gldm_SmallDependenceEmphasis: 0.0073627541851505
# Case-5_exponential_gldm_SmallDependenceHighGrayLevelEmphasis: 0.012156888420909104
# Case-5_exponential_gldm_SmallDependenceLowGrayLevelEmphasis: 0.00616422062621085
# Case-5_gradient_firstorder_10Percentile: 30.80191421508789
# Case-5_gradient_firstorder_90Percentile: 208.4225311279297
# Case-5_gradient_firstorder_Energy: 67999327.01805368
# Case-5_gradient_firstorder_Entropy: 3.333544360550238
# Case-5_gradient_firstorder_InterquartileRange: 94.1805191040039
# Case-5_gradient_firstorder_Kurtosis: 4.442295398050977
# Case-5_gradient_firstorder_Maximum: 480.3651428222656
# Case-5_gradient_firstorder_MeanAbsoluteDeviation: 57.27885301247954
# Case-5_gradient_firstorder_Mean: 105.58198240946133
# Case-5_gradient_firstorder_Median: 86.68574523925781
# Case-5_gradient_firstorder_Minimum: 2.1889708042144775
# Case-5_gradient_firstorder_Range: 478.17617201805115
# Case-5_gradient_firstorder_RobustMeanAbsoluteDeviation: 39.59618911838992
# Case-5_gradient_firstorder_RootMeanSquared: 128.20635316376774
# Case-5_gradient_firstorder_Skewness: 1.2109872932863208
# Case-5_gradient_firstorder_TotalEnergy: 269772720.71371377
# Case-5_gradient_firstorder_Uniformity: 0.12143202166503096
# Case-5_gradient_firstorder_Variance: 5289.313982040937
# Case-5_gradient_glcm_Autocorrelation: 23.29483338837694
# Case-5_gradient_glcm_JointAverage: 4.657113126247173
# Case-5_gradient_glcm_ClusterProminence: 1550.3126049673592
# Case-5_gradient_glcm_ClusterShade: 79.48596799453321
# Case-5_gradient_glcm_ClusterTendency: 18.794204269284624
# Case-5_gradient_glcm_Contrast: 12.372941281789696
# Case-5_gradient_glcm_Correlation: 0.19955245478890984
# Case-5_gradient_glcm_DifferenceAverage: 2.5757340477632273
# Case-5_gradient_glcm_DifferenceEntropy: 2.9440276310147513
# Case-5_gradient_glcm_DifferenceVariance: 5.568993674328388
# Case-5_gradient_glcm_JointEnergy: 0.018011488499373854
# Case-5_gradient_glcm_JointEntropy: 6.435398780436173
# Case-5_gradient_glcm_Imc1: -0.038036131919983215
# Case-5_gradient_glcm_Imc2: 0.42514014113647136
# Case-5_gradient_glcm_Idm: 0.35029764971049965
# Case-5_gradient_glcm_Idmn: 0.9723444111511715
# Case-5_gradient_glcm_Id: 0.4258372422368355
# Case-5_gradient_glcm_Idn: 0.8948551084190055
# Case-5_gradient_glcm_InverseVariance: 0.33269714609275247
# Case-5_gradient_glcm_MaximumProbability: 0.05007009923578824
# Case-5_gradient_glcm_SumEntropy: 4.004328122721719
# Case-5_gradient_glcm_SumSquares: 7.79178638776858
# Case-5_gradient_glrlm_GrayLevelNonUniformity: 426.2202548459561
# Case-5_gradient_glrlm_GrayLevelNonUniformityNormalized: 0.11535724436448772
# Case-5_gradient_glrlm_GrayLevelVariance: 8.91765193421128
# Case-5_gradient_glrlm_HighGrayLevelRunEmphasis: 32.617922589020374
# Case-5_gradient_glrlm_LongRunEmphasis: 1.4631663577552927
# Case-5_gradient_glrlm_LongRunHighGrayLevelEmphasis: 39.903302728224475
# Case-5_gradient_glrlm_LongRunLowGrayLevelEmphasis: 0.22724202285564601
# Case-5_gradient_glrlm_LowGrayLevelRunEmphasis: 0.1434176282443626
# Case-5_gradient_glrlm_RunEntropy: 3.8955647662005015
# Case-5_gradient_glrlm_RunLengthNonUniformity: 3036.9933930571747
# Case-5_gradient_glrlm_RunLengthNonUniformityNormalized: 0.8173962309128933
# Case-5_gradient_glrlm_RunPercentage: 0.8912999014521856
# Case-5_gradient_glrlm_RunVariance: 0.18284635153833972
# Case-5_gradient_glrlm_ShortRunEmphasis: 0.9205078881845167
# Case-5_gradient_glrlm_ShortRunHighGrayLevelEmphasis: 31.180093445644737
# Case-5_gradient_glrlm_ShortRunLowGrayLevelEmphasis: 0.12996778790300098
# Case-5_gradient_glszm_GrayLevelNonUniformity: 92.5528596187175
# Case-5_gradient_glszm_GrayLevelNonUniformityNormalized: 0.08020178476491985
# Case-5_gradient_glszm_GrayLevelVariance: 12.82338576693529
# Case-5_gradient_glszm_HighGrayLevelZoneEmphasis: 54.85961871750433
# Case-5_gradient_glszm_LargeAreaEmphasis: 252.1568457538995
# Case-5_gradient_glszm_LargeAreaHighGrayLevelEmphasis: 2378.2677642980934
# Case-5_gradient_glszm_LargeAreaLowGrayLevelEmphasis: 42.220432952052136
# Case-5_gradient_glszm_LowGrayLevelZoneEmphasis: 0.12229955201563565
# Case-5_gradient_glszm_SizeZoneNonUniformity: 441.5563258232236
# Case-5_gradient_glszm_SizeZoneNonUniformityNormalized: 0.38263113156258544
# Case-5_gradient_glszm_SmallAreaEmphasis: 0.6422528875239206
# Case-5_gradient_glszm_SmallAreaHighGrayLevelEmphasis: 40.40996830875713
# Case-5_gradient_glszm_SmallAreaLowGrayLevelEmphasis: 0.076169667545054
# Case-5_gradient_glszm_ZoneEntropy: 5.76597992158
# Case-5_gradient_glszm_ZonePercentage: 0.27894609620497945
# Case-5_gradient_glszm_ZoneVariance: 239.30517993325907
# Case-5_gradient_gldm_DependenceEntropy: 6.114861852059413
# Case-5_gradient_gldm_DependenceNonUniformity: 574.8506163886874
# Case-5_gradient_gldm_DependenceNonUniformityNormalized: 0.13895349683071972
# Case-5_gradient_gldm_DependenceVariance: 6.130055509367377
# Case-5_gradient_gldm_GrayLevelNonUniformity: 502.36427362823304
# Case-5_gradient_gldm_GrayLevelVariance: 8.553236681137795
# Case-5_gradient_gldm_HighGrayLevelEmphasis: 30.827894609620497
# Case-5_gradient_gldm_LargeDependenceEmphasis: 20.769881556683586
# Case-5_gradient_gldm_LargeDependenceHighGrayLevelEmphasis: 295.8653613729756
# Case-5_gradient_gldm_LargeDependenceLowGrayLevelEmphasis: 3.8053115834231215
# Case-5_gradient_gldm_LowGrayLevelEmphasis: 0.14706931992833502
# Case-5_gradient_gldm_SmallDependenceEmphasis: 0.24968761244006552
# Case-5_gradient_gldm_SmallDependenceHighGrayLevelEmphasis: 13.436714622173048
# Case-5_gradient_gldm_SmallDependenceLowGrayLevelEmphasis: 0.030340262163509886
