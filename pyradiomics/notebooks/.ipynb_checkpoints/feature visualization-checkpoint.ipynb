# %% [markdown]
# # Import data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import os

# %%
path = os.path.join('/home','manos','git','radiomics-features-extraction')
dataset = pd.read_csv(os.path.join(path, 'pyradiomics','data','pyradiomics_extracted_features.csv'))

# %%
selected_features = pd.read_excel(os.path.join(path,'info','info.xlsx'), usecols='D')
selected_features = selected_features.dropna().values.flatten()

# %%
selected_dataset = dataset[selected_features]
selected_dataset
# Out:
#      original_shape_VoxelVolume  original_shape_Sphericity  \
# 0                    554.656982                   0.437226
# 1                   8871.499847                   0.535732
# 2                  22722.888060                   0.437639
# 3                   4078.674316                   0.279094
# 4                    663.074188                   0.520061
# ..                          ...                        ...
# 137                15685.272217                   0.361381
# 138                10137.416498                   0.351518
# 139                 2996.826172                   0.649366
# 140               153826.311066                   0.379710
# 141                 6081.756592                   0.565878
#
#      original_shape_SurfaceArea  original_firstorder_Skewness  \
# 0                    735.572529                      0.094501
# 1                   3837.795614                     -0.390048
# 2                   8853.887148                      0.179656
# 3                   4394.068799                     -0.581958
# 4                    698.539523                     -1.398342
# ..                          ...                           ...
# 137                 8365.835502                      0.198059
# 138                 6426.464533                     -0.075251
# 139                 1530.911130                     -0.560970
# 140                36456.553913                     -0.057095
# 141                 2818.840824                     -1.076953
#
#      original_firstorder_Minimum  original_firstorder_Mean  \
# 0                           80.0                585.615543
# 1                            0.0                732.775343
# 2                            0.0                602.546868
# 3                            0.0                753.854190
# 4                            0.0                949.320621
# ..                           ...                       ...
# 137                          0.0                622.624641
# 138                          0.0                638.426983
# 139                          0.0                765.411405
# 140                          0.0                643.072097
# 141                          0.0                901.007893
#
#      original_firstorder_Maximum  original_firstorder_Kurtosis  \
# 0                         1053.0                      1.557570
# 1                         1433.0                      1.670075
# 2                         1332.0                      1.580534
# 3                         1623.0                      2.067330
# 4                         1390.0                      4.179931
# ..                           ...                           ...
# 137                       2682.0                      1.662679
# 138                       1460.0                      1.731007
# 139                       1255.0                      1.938795
# 140                       1847.0                      1.500179
# 141                       1491.0                      3.801823
#
#      original_glcm_Correlation  original_glcm_Contrast  ...  \
# 0                     0.532580              132.141327  ...
# 1                     0.566143              186.115380  ...
# 2                     0.817053               69.293654  ...
# 3                     0.640859              116.523926  ...
# 4                     0.392271               86.671370  ...
# ..                         ...                     ...  ...
# 137                   0.697215              168.884850  ...
# 138                   0.544471              174.724097  ...
# 139                   0.505941              143.083789  ...
# 140                   0.720614              146.520580  ...
# 141                   0.407331               99.136038  ...
#
#      original_glrlm_LongRunEmphasis  original_glrlm_LowGrayLevelRunEmphasis  \
# 0                          1.258071                                0.021697
# 1                          1.162587                                0.031256
# 2                          1.312236                                0.008361
# 3                          1.147615                                0.021262
# 4                          1.245415                                0.001989
# ..                              ...                                     ...
# 137                        1.185478                                0.047095
# 138                        1.142878                                0.025800
# 139                        1.153215                                0.010443
# 140                        1.177196                                0.053895
# 141                        1.137576                                0.004266
#
#      original_glrlm_HighGrayLevelRunEmphasis  \
# 0                                 554.791672
# 1                                1115.519776
# 2                                 776.191522
# 3                                1113.617383
# 4                                1564.657575
# ..                                       ...
# 137                               916.735449
# 138                               862.751089
# 139                              1126.523862
# 140                               949.464155
# 141                              1433.709375
#
#      original_glrlm_ShortRunLowGrayLevelEmphasis  \
# 0                                       0.021249
# 1                                       0.029239
# 2                                       0.007879
# 3                                       0.020356
# 4                                       0.001954
# ..                                           ...
# 137                                     0.043246
# 138                                     0.023838
# 139                                     0.010377
# 140                                     0.049626
# 141                                     0.004240
#
#      original_glrlm_ShortRunHighGrayLevelEmphasis  \
# 0                                      508.853122
# 1                                     1061.520258
# 2                                      713.134515
# 3                                     1067.632281
# 4                                     1468.267707
# ..                                            ...
# 137                                    871.483117
# 138                                    828.710893
# 139                                   1070.895206
# 140                                    904.544827
# 141                                   1380.302549
#
#      original_glrlm_LongRunLowGrayLevelEmphasis  \
# 0                                      0.023713
# 1                                      0.041129
# 2                                      0.010652
# 3                                      0.025469
# 4                                      0.002148
# ..                                          ...
# 137                                    0.066946
# 138                                    0.035588
# 139                                    0.010718
# 140                                    0.075188
# 141                                    0.004371
#
#      original_glrlm_LongRunHighGrayLevelEmphasis  \
# 0                                     853.045914
# 1                                    1362.173631
# 2                                    1122.838934
# 3                                    1321.729869
# 4                                    2017.892333
# ..                                           ...
# 137                                  1132.014919
# 138                                  1019.781924
# 139                                  1380.847670
# 140                                  1155.984026
# 141                                  1664.313697
#
#      original_gldm_GrayLevelNonUniformity  \
# 0                               45.742779
# 1                               82.703074
# 2                             1449.267402
# 3                              303.573700
# 4                               79.593407
# ..                                    ...
# 137                            922.076657
# 138                            524.496349
# 139                             30.832994
# 140                           1181.195969
# 141                             59.775956
#
#      original_glrlm_RunLengthNonUniformity  original_glrlm_RunPercentage
# 0                              1214.468682                      0.934980
# 1                              2646.342898                      0.951275
# 2                             42587.403314                      0.915287
# 3                              9367.686370                      0.955445
# 4                              1253.568296                      0.929442
# ..                                     ...                           ...
# 137                           35021.091755                      0.945568
# 138                           21230.726587                      0.957029
# 139                             857.126542                      0.954018
# 140                           41038.471995                      0.947355
# 141                            1449.148152                      0.957545
#
# [142 rows x 28 columns]

# %%
selected_dataset.describe()
# Out:
#        original_shape_VoxelVolume  original_shape_Sphericity  \
# count                1.420000e+02                 142.000000
# mean                 6.080755e+04                   0.503191
# std                  1.958340e+05                   0.113198
# min                  2.883911e+02                   0.279094
# 25%                  2.750137e+03                   0.414749
# 50%                  8.961507e+03                   0.499544
# 75%                  3.049054e+04                   0.582145
# max                  1.487439e+06                   0.812880
#
#        original_shape_SurfaceArea  original_firstorder_Skewness  \
# count                  142.000000                    142.000000
# mean                 10796.130583                     -0.457507
# std                  19919.784384                      0.939366
# min                    300.570549                     -3.501654
# 25%                   1842.310133                     -0.976028
# 50%                   4202.820607                     -0.301360
# 75%                   9379.154338                      0.134550
# max                 152198.367140                      1.291258
#
#        original_firstorder_Minimum  original_firstorder_Mean  \
# count                   142.000000                142.000000
# mean                     38.098592                732.451782
# std                      69.013033                172.433554
# min                       0.000000                359.873363
# 25%                       0.000000                599.677142
# 50%                       0.000000                731.592454
# 75%                      42.750000                864.144103
# max                     313.000000               1034.103754
#
#        original_firstorder_Maximum  original_firstorder_Kurtosis  \
# count                   142.000000                    142.000000
# mean                   1586.267606                      3.222745
# std                     513.271069                      2.776913
# min                     871.000000                      1.281462
# 25%                    1253.500000                      1.735714
# 50%                    1468.500000                      2.142099
# 75%                    1721.000000                      3.254874
# max                    3774.000000                     18.224214
#
#        original_glcm_Correlation  original_glcm_Contrast  ...  \
# count                 142.000000              142.000000  ...
# mean                    0.631871               95.139658  ...
# std                     0.150729               56.579688  ...
# min                    -0.004614                7.954506  ...
# 25%                     0.546041               47.966890  ...
# 50%                     0.641489               91.581991  ...
# 75%                     0.733384              132.248784  ...
# max                     0.932812              300.127516  ...
#
#        original_glrlm_LongRunEmphasis  original_glrlm_LowGrayLevelRunEmphasis  \
# count                      142.000000                              142.000000
# mean                         1.343531                                0.016922
# std                          0.408531                                0.019461
# min                          1.100702                                0.000656
# 25%                          1.160828                                0.004861
# 50%                          1.221687                                0.008923
# 75%                          1.386288                                0.021243
# max                          5.009277                                0.085116
#
#        original_glrlm_HighGrayLevelRunEmphasis  \
# count                               142.000000
# mean                                987.895196
# std                                 387.498431
# min                                 241.318765
# 25%                                 679.888736
# 50%                                1014.607065
# 75%                                1225.385147
# max                                1790.708968
#
#        original_glrlm_ShortRunLowGrayLevelEmphasis  \
# count                                   142.000000
# mean                                      0.015580
# std                                       0.017200
# min                                       0.000554
# 25%                                       0.004657
# 50%                                       0.008631
# 75%                                       0.019662
# max                                       0.077119
#
#        original_glrlm_ShortRunHighGrayLevelEmphasis  \
# count                                    142.000000
# mean                                     914.876558
# std                                      357.004450
# min                                      231.415812
# 25%                                      638.690985
# 50%                                      952.444601
# 75%                                     1151.130186
# max                                     1698.977566
#
#        original_glrlm_LongRunLowGrayLevelEmphasis  \
# count                                  142.000000
# mean                                     0.024814
# std                                      0.035446
# min                                      0.001033
# 25%                                      0.006028
# 50%                                      0.011055
# 75%                                      0.025148
# max                                      0.202795
#
#        original_glrlm_LongRunHighGrayLevelEmphasis  \
# count                                   142.000000
# mean                                   1438.758125
# std                                     887.644294
# min                                     289.370565
# 25%                                     925.777174
# 50%                                    1322.426640
# 75%                                    1775.409953
# max                                    8029.369114
#
#        original_gldm_GrayLevelNonUniformity  \
# count                            142.000000
# mean                            2428.012263
# std                             6086.228903
# min                                7.956989
# 25%                              144.224462
# 50%                              409.487389
# 75%                             1096.172576
# max                            45942.852533
#
#        original_glrlm_RunLengthNonUniformity  original_glrlm_RunPercentage
# count                             142.000000                    142.000000
# mean                            26601.729152                      0.918281
# std                             45828.628593                      0.053757
# min                               172.629098                      0.603573
# 25%                              3315.807699                      0.906165
# 50%                              8325.637501                      0.935778
# 75%                             27913.356430                      0.951918
# max                            295967.607219                      0.971878
#
# [8 rows x 28 columns]

# %% [markdown]
# # Plot features as a heatmap
#
# A heat map gives the correlation of features to each other, red indicating positive correlation, and blue negative.  A heatmap may be clustered to show groupings of features that are similar.

# %%
import seaborn as sns

corr = selected_dataset.corr()

# Set up the matplotlib figure, make it big!
f, ax = plt.subplots(figsize=(15, 10))

# Draw the heatmap using seaborn
sns.heatmap(corr, vmax=.8, square=True)

# %% [markdown]
# # Cluster the heatmap
#
# Though useful, heatmaps tell a much better story if the features are clustered.  Here we take a smaller subset of the features and cluster.  In the [dendrogram](https://en.wikipedia.org/wiki/Dendrogram), there are 2 major groups, and many smaller groupings based on features.

# %%
# Choose a subset of features for clustering
dd = selected_dataset.iloc[:,1:50]

pp = sns.clustermap(dd.corr(), linewidths=.5, figsize=(13,13))
_ = plt.setp(pp.ax_heatmap.get_yticklabels(), rotation=0)

plt.show()

# %% [markdown]
# # Distributions

# %%
ax = selected_dataset.hist(alpha=0.5, figsize=(20,15))

# %%
# ax = selected_dataset.plot.kde()
