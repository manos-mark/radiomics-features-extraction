# %% [markdown]
# # 1. Data preparation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 1.1. Data set structure
#
# First step, I want to have an overview about my dataset. There are no missing values, but there is very high variance.

# %%
dataset = pd.read_csv('../../data/extracted-features/results.csv')
dataset
# Out:
#                 Mask        Image  original_shape_VoxelVolume  \
# 0    R01-127_roi.nii  R01-127.nii                 6646.222923
# 1    R01-064_roi.nii  R01-064.nii                 3366.088867
# 2    R01-118_roi.nii  R01-118.nii               154492.126465
# 3    R01-044_roi.nii  R01-044.nii                  707.652683
# 4    R01-024_roi.nii  R01-024.nii                 4905.527134
# ..               ...          ...                         ...
# 137  R01-030_roi.nii  R01-030.nii                 1754.061290
# 138  R01-074_roi.nii  R01-074.nii                 9448.241449
# 139  R01-114_roi.nii  R01-114.nii               511574.245594
# 140  R01-097_roi.nii  R01-097.nii                16921.183157
# 141  R01-019_roi.nii  R01-019.nii                 4264.522552
#
#      original_shape_MeshVolume  original_shape_SurfaceArea  \
# 0                  6620.933051                 3821.238084
# 1                  3297.932943                 1870.232366
# 2                153863.610586                29776.235984
# 3                   690.997678                 1016.191502
# 4                  4877.243809                 2747.608401
# ..                         ...                         ...
# 137                1735.342810                 1513.769798
# 138                9397.864448                 5875.774846
# 139              510811.902931                55123.281293
# 140               16746.470800                 6002.241491
# 141                4237.058640                 3095.842267
#
#      original_shape_SurfaceVolumeRatio  original_shape_Sphericity  \
# 0                             0.577145                   0.446231
# 1                             0.567092                   0.572906
# 2                             0.193524                   0.466342
# 3                             1.470615                   0.371957
# 4                             0.563353                   0.506188
# ..                                 ...                        ...
# 137                           0.872317                   0.461333
# 138                           0.625224                   0.366526
# 139                           0.107913                   0.560604
# 140                           0.358418                   0.527375
# 141                           0.730658                   0.409024
#
#      original_shape_Maximum3DDiameter  original_shape_Maximum2DDiameterSlice  \
# 0                           42.351097                              41.211769
# 1                           52.086588                              14.925760
# 2                          148.169042                              75.007242
# 3                           32.898135                              30.636614
# 4                           47.004263                              27.938821
# ..                                ...                                    ...
# 137                         25.493964                              25.144558
# 138                         53.295508                              50.481472
# 139                        236.708373                              79.396354
# 140                         63.023743                              47.931452
# 141                         45.302329                              43.633914
#
#      original_shape_Maximum2DDiameterColumn  ...  \
# 0                                 38.654876  ...
# 1                                 51.939907  ...
# 2                                146.583008  ...
# 3                                 26.940836  ...
# 4                                 30.427050  ...
# ..                                      ...  ...
# 137                               23.884997  ...
# 138                               37.477322  ...
# 139                              235.893133  ...
# 140                               60.832448  ...
# 141                               44.901150  ...
#
#      lbp-3D-k_gldm_GrayLevelNonUniformity  lbp-3D-k_gldm_GrayLevelVariance  \
# 0                            17568.232131                         0.107344
# 1                              814.020852                         0.130997
# 2                            27212.449782                         0.174788
# 3                             1678.344142                         0.061102
# 4                             8310.601509                         0.143750
# ..                                    ...                              ...
# 137                           2867.651886                         0.134601
# 138                          18708.772652                         0.114729
# 139                          62708.310808                         0.207749
# 140                           3737.838199                         0.171312
# 141                           7161.095898                         0.112453
#
#      lbp-3D-k_gldm_HighGrayLevelEmphasis  \
# 0                               1.366904
# 1                               1.465095
# 2                               1.677255
# 3                               1.196130
# 4                               1.522119
# ..                                   ...
# 137                             1.480887
# 138                             1.396623
# 139                             1.883348
# 140                             1.658459
# 141                             1.387380
#
#      lbp-3D-k_gldm_LargeDependenceEmphasis  \
# 0                               435.038264
# 1                               273.110607
# 2                               310.474449
# 3                               357.702929
# 4                               362.528292
# ..                                     ...
# 137                             331.925586
# 138                             409.120428
# 139                             300.176287
# 140                             284.695392
# 141                             364.342570
#
#      lbp-3D-k_gldm_LargeDependenceHighGrayLevelEmphasis  \
# 0                                           447.886326
# 1                                           297.173164
# 2                                           365.343731
# 3                                           361.049686
# 4                                           419.715021
# ..                                                 ...
# 137                                         353.299439
# 138                                         428.093822
# 139                                         415.043361
# 140                                         329.485403
# 141                                         393.022621
#
#      lbp-3D-k_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                           431.826248
# 1                                           267.094968
# 2                                           296.757129
# 3                                           356.866240
# 4                                           348.231610
# ..                                                 ...
# 137                                         326.582123
# 138                                         404.377080
# 139                                         271.459519
# 140                                         273.497890
# 141                                         357.172557
#
#      lbp-3D-k_gldm_LowGrayLevelEmphasis  \
# 0                              0.908274
# 1                              0.883726
# 2                              0.830686
# 3                              0.950968
# 4                              0.869470
# ..                                  ...
# 137                            0.879778
# 138                            0.900844
# 139                            0.779163
# 140                            0.835385
# 141                            0.903155
#
#      lbp-3D-k_gldm_SmallDependenceEmphasis  \
# 0                                 0.017466
# 1                                 0.019400
# 2                                 0.015801
# 3                                 0.020960
# 4                                 0.011873
# ..                                     ...
# 137                               0.022578
# 138                               0.018901
# 139                               0.010530
# 140                               0.021999
# 141                               0.010737
#
#      lbp-3D-k_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                             0.060178
# 1                                             0.065205
# 2                                             0.051458
# 3                                             0.064607
# 4                                             0.038674
# ..                                                 ...
# 137                                           0.078591
# 138                                           0.065576
# 139                                           0.034199
# 140                                           0.074036
# 141                                           0.033332
#
#      lbp-3D-k_gldm_SmallDependenceLowGrayLevelEmphasis
# 0                                             0.006788
# 1                                             0.007949
# 2                                             0.006886
# 3                                             0.010049
# 4                                             0.005173
# ..                                                 ...
# 137                                           0.008575
# 138                                           0.007232
# 139                                           0.004613
# 140                                           0.008990
# 141                                           0.005088
#
# [142 rows x 1564 columns]

# %%
dataset.describe()
# Out:
#        original_shape_VoxelVolume  original_shape_MeshVolume  \
# count                1.420000e+02               1.420000e+02
# mean                 6.080755e+04               6.068265e+04
# std                  1.958340e+05               1.956766e+05
# min                  2.883911e+02               2.812703e+02
# 25%                  2.750137e+03               2.734713e+03
# 50%                  8.961507e+03               8.851577e+03
# 75%                  3.049054e+04               3.043368e+04
# max                  1.487439e+06               1.486631e+06
#
#        original_shape_SurfaceArea  original_shape_SurfaceVolumeRatio  \
# count                  142.000000                         142.000000
# mean                 10796.130583                           0.540578
# std                  19919.784384                           0.302428
# min                    300.570549                           0.073790
# 25%                   1842.310133                           0.293432
# 50%                   4202.820607                           0.502036
# 75%                   9379.154338                           0.730071
# max                 152198.367140                           1.470615
#
#        original_shape_Sphericity  original_shape_Maximum3DDiameter  \
# count                 142.000000                        142.000000
# mean                    0.503191                         79.637499
# std                     0.113198                         81.878779
# min                     0.279094                         12.977257
# 25%                     0.414749                         36.626020
# 50%                     0.499544                         56.220460
# 75%                     0.582145                         81.894960
# max                     0.812880                        562.790734
#
#        original_shape_Maximum2DDiameterSlice  \
# count                             142.000000
# mean                               43.536427
# std                                22.473264
# min                                12.749621
# 25%                                26.607213
# 50%                                38.034065
# 75%                                56.394116
# max                               121.822600
#
#        original_shape_Maximum2DDiameterColumn  \
# count                              142.000000
# mean                                72.628203
# std                                 80.904792
# min                                 11.636423
# 25%                                 29.075459
# 50%                                 48.570911
# 75%                                 75.870716
# max                                560.853928
#
#        original_shape_Maximum2DDiameterRow  original_shape_MajorAxisLength  \
# count                           142.000000                      142.000000
# mean                             72.845955                       65.499930
# std                              78.233669                       72.255143
# min                              11.588368                       10.380858
# 25%                              28.050569                       27.491722
# 50%                              49.780724                       42.959259
# 75%                              76.039318                       67.914106
# max                             530.822093                      520.310068
#
#        ...  lbp-3D-k_gldm_GrayLevelNonUniformity  \
# count  ...                            142.000000
# mean   ...                          26368.776944
# std    ...                          46538.058229
# min    ...                            186.000000
# 25%    ...                           2966.601633
# 50%    ...                           7318.407278
# 75%    ...                          23598.460274
# max    ...                         241011.270413
#
#        lbp-3D-k_gldm_GrayLevelVariance  lbp-3D-k_gldm_HighGrayLevelEmphasis  \
# count                       142.000000                           142.000000
# mean                          0.136186                             1.504018
# std                           0.041302                             0.180476
# min                           0.000000                             1.000000
# 25%                           0.113007                             1.389622
# 50%                           0.145368                             1.529594
# 75%                           0.168269                             1.642344
# max                           0.213428                             1.926290
#
#        lbp-3D-k_gldm_LargeDependenceEmphasis  \
# count                             142.000000
# mean                              352.788590
# std                                71.152286
# min                               184.000000
# 25%                               308.751571
# 50%                               340.371050
# 75%                               390.722461
# max                               523.329436
#
#        lbp-3D-k_gldm_LargeDependenceHighGrayLevelEmphasis  \
# count                                         142.000000
# mean                                          388.721189
# std                                            59.378318
# min                                           184.000000
# 25%                                           353.930173
# 50%                                           380.722489
# 75%                                           421.036919
# max                                           532.288879
#
#        lbp-3D-k_gldm_LargeDependenceLowGrayLevelEmphasis  \
# count                                         142.000000
# mean                                          343.805440
# std                                            74.875866
# min                                           171.179947
# 25%                                           294.805884
# 50%                                           332.601415
# 75%                                           383.264148
# max                                           521.089576
#
#        lbp-3D-k_gldm_LowGrayLevelEmphasis  \
# count                          142.000000
# mean                             0.873996
# std                              0.045119
# min                              0.768428
# 25%                              0.839414
# 50%                              0.867602
# 75%                              0.902595
# max                              1.000000
#
#        lbp-3D-k_gldm_SmallDependenceEmphasis  \
# count                             142.000000
# mean                                0.015180
# std                                 0.003606
# min                                 0.008471
# 25%                                 0.012658
# 50%                                 0.015112
# 75%                                 0.017493
# max                                 0.026712
#
#        lbp-3D-k_gldm_SmallDependenceHighGrayLevelEmphasis  \
# count                                         142.000000
# mean                                            0.050157
# std                                             0.013308
# min                                             0.011359
# 25%                                             0.041309
# 50%                                             0.050281
# 75%                                             0.058623
# max                                             0.094076
#
#        lbp-3D-k_gldm_SmallDependenceLowGrayLevelEmphasis
# count                                         142.000000
# mean                                            0.006436
# std                                             0.001459
# min                                             0.004126
# 25%                                             0.005314
# 50%                                             0.006371
# 75%                                             0.007221
# max                                             0.011930
#
# [8 rows x 1562 columns]

# %% [markdown]
# ## 1.2. Remove categorical columns

# %%
dataset.drop(axis=1, labels=['ID', 'Mask', 'Image'], inplace=True)
columns = dataset.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-bf3ac95ffaa0> in <module>
# ----> 1 dataset.drop(axis=1, labels=['ID', 'Mask', 'Image'], inplace=True)
#       2 columns = dataset.columns
#
# ~/anaconda3/envs/radiomics/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/anaconda3/envs/radiomics/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/anaconda3/envs/radiomics/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/anaconda3/envs/radiomics/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['ID'] not found in axis"

# %% [markdown]
# ## 1.2. Imputer

# %%
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imputed_dataset = imp_mean.fit_transform(dataset)
imputed_dataset = pd.DataFrame(imputed_dataset, columns=columns)

# %% [markdown]
# ## 1.3. Scale dataset

# %%
scaler = StandardScaler()
scaled_dataset = scaler.fit_transform(imputed_dataset)
scaled_dataset = pd.DataFrame(scaled_dataset, columns=columns)
scaled_dataset

# %%
scaled_dataset.describe()

# %% [markdown]
# # 2. Data Visualization

# %%
# from sklearn import manifold
# from sklearn.metrics import euclidean_distances
# from sklearn.decomposition import PCA

# similarities = euclidean_distances(scaled_dataset)


# seed = np.random.RandomState(seed=3)

# mds = manifold.MDS(n_components=2, max_iter=5000, eps=1e-12, random_state=seed,
#                    n_init=10,
#                    dissimilarity="precomputed", n_jobs=1, metric=False)
# pos = mds.fit_transform(similarities)

# %%
import pandas as pd
import seaborn as sns

# Construct a pandas dataframe from the samples
d = pd.DataFrame(data=scaled_dataset, columns=scaled_dataset.columns)
corr = d.corr()

# Set up the matplotlib figure, make it big!
f, ax = plt.subplots(figsize=(15, 10))

# Draw the heatmap using seaborn
sns.heatmap(corr, vmax=.8, square=True)
plt.show()

# %%
# Choose a subset of features for clustering
dd = d.iloc[:,1:50]

pp = sns.clustermap(dd.corr(), linewidths=.5, figsize=(13,13))
_ = plt.setp(pp.ax_heatmap.get_yticklabels(), rotation=0)

plt.show()

# %% [markdown]
# # 2. Feature selection
#
# Perform multiple techiques of feature selection in order to compare them.

# %% [markdown]
# # 3. Feature extraction
#
# Perform multiple techiques of feature extraction in order to compare them.

# %% [markdown]
# ## 3.1. PCA
#
# Perform PCA using the scaled dataset, while preserving 99% of the training set's variance.

# %%
pca = PCA(n_components=0.95)
reduced_dataset = pca.fit_transform(scaled_dataset)
reduced_dataset = pd.DataFrame(reduced_dataset)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.32353211, 0.19455842, 0.07109174, 0.05540727, 0.04845371,
#        0.03882905, 0.02468397, 0.02128251, 0.01939238, 0.01631158,
#        0.01454536, 0.01325816, 0.0113388 , 0.01021395, 0.00847357,
#        0.00785542, 0.00735366, 0.00594481, 0.00559962, 0.0054668 ,
#        0.00524277, 0.00495009, 0.0043242 , 0.00402276, 0.00376249,
#        0.00346265, 0.00325574, 0.00314623, 0.00279623, 0.00265146,
#        0.00253008, 0.00235972, 0.00234595, 0.0021959 ])

# %%
reduced_dataset
# Out:
#             0          1          2          3          4         5   \
# 0    12.372470  -4.416088 -15.017475   0.197794 -10.609170  7.783182
# 1   -17.315603 -10.474244  14.950790   4.184207   0.692320  1.221895
# 2   -18.941172  10.773417  -4.227903  -1.062399   5.404409  0.997700
# 3    20.497840 -27.661018  -8.199374  13.258040   1.738378  0.161922
# 4     9.345105  -8.499574  -8.876822  -9.875690   2.030811 -2.619141
# ..         ...        ...        ...        ...        ...       ...
# 137 -15.965446  -7.405406   0.366745  -1.048638  -3.909767  4.192648
# 138 -10.024957   0.454103  -7.674282  -1.644073  -5.234989  1.258066
# 139  -3.654434  28.244998   2.892264   0.678230   0.888848 -0.693112
# 140 -38.541451  -4.596566   2.089812  -2.925153  17.393317 -1.536050
# 141  18.280762 -11.654695  -7.679778  -6.703352   1.478024  4.541883
#
#            6          7         8          9   ...        24        25  \
# 0    4.870171   2.638607 -3.433725  -9.084434  ...  1.722521  0.813686
# 1   -5.106153   0.267429  7.264478   5.902128  ... -0.816905 -0.099636
# 2    1.813209  -1.802870 -9.838638   4.479197  ... -1.113416 -0.070417
# 3    2.004096   3.990448 -1.848468  -5.905846  ... -5.391967 -3.545194
# 4   -2.108221  -4.881016 -3.883980   2.092629  ... -1.315574 -4.487739
# ..        ...        ...       ...        ...  ...       ...       ...
# 137 -3.708620  -0.296101  6.855780   0.299429  ... -0.404368  0.913613
# 138  1.045787  -1.949472  5.029705   4.469431  ... -2.427652  2.331576
# 139 -1.251614 -11.418007 -9.901219  -0.739684  ... -1.300901 -1.109363
# 140 -2.214112   9.921113 -6.825601   3.524971  ...  0.248957 -0.338019
# 141 -4.203164 -11.424484  1.433152 -11.106949  ...  1.556736  4.075612
#
#            26        27        28        29        30        31        32  \
# 0    1.474268 -0.129584  1.938165  0.755522 -0.284618 -2.151967 -1.387982
# 1   -1.760084 -0.204114 -0.805074 -3.456550  1.086176  1.259974 -0.536878
# 2   -0.686735  0.995891  0.604392  0.544497 -0.907939  0.020810 -0.471116
# 3   -0.783715  2.913215  3.440641  7.549287 -3.349595 -1.647898 -0.571840
# 4   -0.866184 -4.983379  2.489015 -2.183437  0.246638 -0.967943  2.725636
# ..        ...       ...       ...       ...       ...       ...       ...
# 137 -0.395798  1.427877  0.882707  0.903442  1.628899 -0.355203  1.936110
# 138 -1.201429  3.275413  2.893244  2.107638  1.729648  2.553209  2.540899
# 139  2.500174  0.228419 -0.392624 -0.384203  0.260678 -5.069614  2.104877
# 140  3.215790  1.985184 -2.885591 -0.684296 -2.351163  2.136547 -2.557774
# 141 -1.030107  2.509813 -0.074935 -2.605078  1.546956  1.214206 -0.128169
#
#            33
# 0    0.972798
# 1    2.638906
# 2   -0.549992
# 3   -0.333527
# 4   -0.750144
# ..        ...
# 137 -0.303859
# 138 -0.607886
# 139  1.202002
# 140  6.328292
# 141 -3.563080
#
# [142 rows x 34 columns]

# %%
def scree_plot(pca):
    '''
    Creates a scree plot associated with the principal components
    
    INPUT: pca = the instance of PCA in scikit learn
    
    OUTPUT: None
    '''
    
    num_components = len(pca.explained_variance_ratio_)
    ind = np.arange(num_components)
    vals = pca.explained_variance_ratio_
    
    plt.figure(figsize=(10, 6))
    ax = plt.subplot(111)
    cumvals = np.cumsum(vals)
    ax.bar(ind, vals)
    ax.plot(ind, cumvals)
    
    for i in range(num_components):
        ax.annotate(r"%s%%" % ((str(vals[i]*100)[:4])), (ind[i]+0.2, vals[i]), va="bottom", ha="center", fontsize=12)
        
    ax.xaxis.set_tick_params(width=0)
    ax.yaxis.set_tick_params(width=2, length=12)
    
    ax.set_xlabel("Principal Component")
    ax.set_ylabel("Variance Explained (%)")
    plt.title('Explained Variance Per Principal Component')
    
scree_plot(pca)
