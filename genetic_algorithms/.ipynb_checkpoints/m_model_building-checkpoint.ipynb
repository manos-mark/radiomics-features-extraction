# %%
import pandas
import csv
pandas.set_option('display.max_columns', None)  # or 1000
pandas.set_option('display.max_rows', None)

rad_labels = pandas.read_csv(r"../dataset/radiogenomics_labels.csv")
rad_labels
# Out:
#      Case ID Patient affiliation  Age at Histological Diagnosis  \
# 0    AMC-001            Stanford                             34
# 1    AMC-002            Stanford                             33
# 2    AMC-003            Stanford                             69
# 3    AMC-004            Stanford                             80
# 4    AMC-005            Stanford                             76
# 5    AMC-006            Stanford                             80
# 6    AMC-007            Stanford                             56
# 7    AMC-008            Stanford                             65
# 8    AMC-009            Stanford                             61
# 9    AMC-010            Stanford                             42
# 10   AMC-011            Stanford                             66
# 11   AMC-012            Stanford                             70
# 12   AMC-013            Stanford                             67
# 13   AMC-014            Stanford                             78
# 14   AMC-015            Stanford                             58
# 15   AMC-016            Stanford                             65
# 16   AMC-017            Stanford                             67
# 17   AMC-018            Stanford                             69
# 18   AMC-019            Stanford                             68
# 19   AMC-020            Stanford                             61
# 20   AMC-021            Stanford                             78
# 21   AMC-022            Stanford                             77
# 22   AMC-023            Stanford                             76
# 23   AMC-024            Stanford                             67
# 24   AMC-025            Stanford                             77
# 25   AMC-026            Stanford                             76
# 26   AMC-027            Stanford                             68
# 27   AMC-028            Stanford                             64
# 28   AMC-029            Stanford                             74
# 29   AMC-030            Stanford                             69
# 30   AMC-031            Stanford                             66
# 31   AMC-032            Stanford                             52
# 32   AMC-033            Stanford                             61
# 33   AMC-034            Stanford                             79
# 34   AMC-035            Stanford                             24
# 35   AMC-036            Stanford                             45
# 36   AMC-037            Stanford                             61
# 37   AMC-038            Stanford                             66
# 38   AMC-039            Stanford                             69
# 39   AMC-040            Stanford                             77
# 40   AMC-041            Stanford                             64
# 41   AMC-042            Stanford                             66
# 42   AMC-043            Stanford                             79
# 43   AMC-044            Stanford                             67
# 44   AMC-045            Stanford                             60
# 45   AMC-046            Stanford                             80
# 46   AMC-047            Stanford                             69
# 47   AMC-048            Stanford                             72
# 48   AMC-049            Stanford                             75
# 49   R01-001            Stanford                             79
# 50   R01-002            Stanford                             65
# 51   R01-003                  VA                             65
# 52   R01-004                  VA                             67
# 53   R01-005            Stanford                             84
# 54   R01-006                  VA                             62
# 55   R01-007                  VA                             68
# 56   R01-008            Stanford                             73
# 57   R01-009                  VA                             59
# 58   R01-010                  VA                             72
# 59   R01-011            Stanford                             65
# 60   R01-012            Stanford                             70
# 61   R01-013            Stanford                             46
# 62   R01-014            Stanford                             52
# 63   R01-015                  VA                             74
# 64   R01-016                  VA                             64
# 65   R01-017            Stanford                             77
# 66   R01-018                  VA                             67
# 67   R01-019                  VA                             71
# 68   R01-020            Stanford                             63
# 69   R01-021            Stanford                             61
# 70   R01-022                  VA                             62
# 71   R01-023                  VA                             81
# 72   R01-024                  VA                             52
# 73   R01-025                  VA                             68
# 74   R01-026            Stanford                             59
# 75   R01-027                  VA                             76
# 76   R01-028                  VA                             67
# 77   R01-029            Stanford                             76
# 78   R01-030                  VA                             86
# 79   R01-031                  VA                             64
# 80   R01-032                  VA                             63
# 81   R01-033                  VA                             69
# 82   R01-034                  VA                             64
# 83   R01-035                  VA                             78
# 84   R01-036                  VA                             43
# 85   R01-037                  VA                             84
# 86   R01-038                  VA                             59
# 87   R01-039                  VA                             78
# 88   R01-040                  VA                             64
# 89   R01-041                  VA                             57
# 90   R01-042                  VA                             76
# 91   R01-043                  VA                             81
# 92   R01-044                  VA                             72
# 93   R01-045                  VA                             66
# 94   R01-046                  VA                             66
# 95   R01-047                  VA                             87
# 96   R01-048            Stanford                             77
# 97   R01-049            Stanford                             70
# 98   R01-050            Stanford                             73
# 99   R01-051            Stanford                             70
# 100  R01-052                  VA                             75
# 101  R01-053                  VA                             62
# 102  R01-054                  VA                             56
# 103  R01-055                  VA                             69
# 104  R01-056                  VA                             71
# 105  R01-057                  VA                             65
# 106  R01-058                  VA                             63
# 107  R01-059                  VA                             67
# 108  R01-060                  VA                             53
# 109  R01-061                  VA                             67
# 110  R01-062                  VA                             72
# 111  R01-063                  VA                             65
# 112  R01-064                  VA                             81
# 113  R01-065                  VA                             80
# 114  R01-066                  VA                             67
# 115  R01-067                  VA                             65
# 116  R01-068                  VA                             63
# 117  R01-069                  VA                             70
# 118  R01-070                  VA                             66
# 119  R01-071                  VA                             72
# 120  R01-072                  VA                             70
# 121  R01-073                  VA                             70
# 122  R01-074            Stanford                             78
# 123  R01-075            Stanford                             86
# 124  R01-076            Stanford                             62
# 125  R01-077            Stanford                             75
# 126  R01-078            Stanford                             74
# 127  R01-079            Stanford                             85
# 128  R01-080                  VA                             71
# 129  R01-081                  VA                             47
# 130  R01-082                  VA                             69
# 131  R01-083                  VA                             68
# 132  R01-084                  VA                             63
# 133  R01-085                  VA                             70
# 134  R01-086                  VA                             68
# 135  R01-087                  VA                             68
# 136  R01-088                  VA                             68
# 137  R01-089            Stanford                             74
# 138  R01-090            Stanford                             76
# 139  R01-091            Stanford                             64
# 140  R01-092                  VA                             73
# 141  R01-093                  VA                             83
# 142  R01-094                  VA                             63
# 143  R01-095                  VA                             74
# 144  R01-096                  VA                             70
# 145  R01-097                  VA                             70
# 146  R01-098            Stanford                             66
# 147  R01-099            Stanford                             51
# 148  R01-100            Stanford                             74
# 149  R01-101            Stanford                             74
# 150  R01-102            Stanford                             73
# 151  R01-103            Stanford                             80
# 152  R01-104            Stanford                             76
# 153  R01-105            Stanford                             81
# 154  R01-106            Stanford                             63
# 155  R01-107            Stanford                             83
# 156  R01-108                  VA                             77
# 157  R01-109                  VA                             69
# 158  R01-110                  VA                             59
# 159  R01-111                  VA                             59
# 160  R01-112                  VA                             78
# 161  R01-113                  VA                             78
# 162  R01-114                  VA                             71
# 163  R01-115                  VA                             67
# 164  R01-116                  VA                             54
# 165  R01-117                  VA                             65
# 166  R01-118                  VA                             80
# 167  R01-119                  VA                             67
# 168  R01-120                  VA                             80
# 169  R01-121                  VA                             72
# 170  R01-122                  VA                             69
# 171  R01-123                  VA                             69
# 172  R01-124                  VA                             72
# 45              46             1978.0  Not Assessed
# 46              50             1993.0  Not Assessed
# 47              30             1979.0  Not Assessed
# 48              30             1962.0  Not Assessed
# 49              37             1967.0            0%
# 50             NaN                NaN            0%
# 51              38                NaN            0%
# 52              10             1965.0            0%
# 53              20             1951.0            0%
# 54   Not Collected                NaN            0%
# 55              15             1968.0            0%
# 56             NaN                NaN      >0 - 25%
# 57             100                NaN            0%
# 58              60             1985.0      >0 - 25%
# 59             NaN                NaN            0%
# 60             NaN                NaN      50 - 75%
# 61              15             1974.0            0%
# 62               1             1967.0      25 - 50%
# 63             NaN                NaN            0%
# 64   Not Collected                NaN            0%
# 65              20             1966.0   75 - < 100%
# 66              10             1941.0            0%
# 67              42             1974.0            0%
# 68             NaN                NaN            0%
# 69             NaN                NaN      >0 - 25%
# 70             NaN                NaN      25 - 50%
# 71              10             1985.0            0%
# 72              53                NaN            0%
# 73              40                NaN            0%
# 74             NaN                NaN            0%
# 75              50             1993.0            0%
# 76              80             1986.0            0%
# 77              60             1963.0            0%
# 78              30             1968.0      >0 - 25%
# 79              46             1985.0            0%
# 80              20             1978.0            0%
# 81              35             1975.0            0%
# 82             NaN                NaN      >0 - 25%
# 83              90                NaN            0%
# 84   Not Collected             1943.0            0%
# 85              10             1936.0            0%
# 86              80             1992.0            0%
# 87              54             1992.0            0%
# 88              30             1992.0            0%
# 89              10             1935.0            0%
# 90              50                NaN            0%
# 91              25                NaN      >0 - 25%
# 92             120             1992.0      >0 - 25%
# 93              50             1985.0            0%
# 94              75             1989.0            0%
# 95              50             1978.0            0%
# 96               8             1945.0            0%
# 97              25                NaN            0%
# 98              50                NaN            0%
# 99             NaN                NaN            0%
# 100            NaN                NaN            0%
# 101             34                NaN            0%
# 102             25                NaN            0%
# 103             54                NaN            0%
# 104             22             1974.0            0%
# 105             30                NaN      50 - 75%
# 106            NaN                NaN      >0 - 25%
# 107             60             1984.0      >0 - 25%
# 108             35                NaN      >0 - 25%
# 109             43             1992.0            0%
# 110             80             1985.0            0%
# 111             40             1991.0            0%
# 112             34                NaN            0%
# 113             38                NaN            0%
# 114             51             1994.0            0%
# 115             50             1988.0            0%
# 116             40             1992.0            0%
# 117             45             1987.0      >0 - 25%
# 118              8                NaN            0%
# 119             10                NaN            0%
# 120            120                NaN            0%
# 121             80             1994.0            0%
# 122             35             1968.0      >0 - 25%
# 123              8             1942.0            0%
# 124             14             1957.0      25 - 50%
# 125            NaN                NaN      >0 - 25%
# 126             30             1967.0      >0 - 25%
# 127             15             1944.0      >0 - 25%
# 128             40             1964.0   75 - < 100%
# 129            NaN                NaN          100%
# 130             50                NaN      >0 - 25%
# 131             50                NaN            0%
# 132             90                NaN            0%
# 133             70             1974.0            0%
# 134             25                NaN            0%
# 135             10                NaN      50 - 75%
# 136             50             1988.0      >0 - 25%
# 137             60             1983.0            0%
# 138             10                NaN            0%
# 139             22                NaN            0%
# 140             50                NaN            0%
# 141             50                NaN            0%
# 142             80             1983.0            0%
# 143             50                NaN      >0 - 25%
# 144             56                NaN      >0 - 25%
# 145             30                NaN            0%
# 146  Not Collected                NaN      >0 - 25%
# 147            NaN                NaN            0%
# 148             30             1967.0      50 - 75%
# 149             60                NaN            0%
# 150              8             1962.0            0%
# 151             40             1970.0            0%
# 152            NaN                NaN      50 - 75%
# 153  Not Collected             1969.0      >0 - 25%
# 154             40             1994.0            0%
# 155            NaN                NaN      >0 - 25%
# 156             80             1979.0            0%
# 157             50             1994.0      >0 - 25%
# 158             70             1994.0            0%
# 159             45                NaN            0%
# 160             90                NaN            0%
# 161             30             1951.0      >0 - 25%
# 162             65             1965.0            0%
# 163             60                NaN            0%
# 164             20                NaN            0%
# 165             45                NaN      >0 - 25%
# 166             45             1981.0            0%
# 167             52                NaN            0%
# 168              1                NaN      50 - 75%
# 169            120                NaN            0%
# 170             50             1988.0      >0 - 25%
# 171             20             1969.0   75 - < 100%
# 172             63             1989.0            0%
# 173             90                NaN            0%
# 174             18             1964.0      >0 - 25%
# 175            NaN                NaN   75 - < 100%
# 176            NaN                NaN            0%
# 177            100             1981.0      >0 - 25%
# 178             60             1969.0      >0 - 25%
# 179              2             1960.0      50 - 75%
# 180              1             1968.0      25 - 50%
# 181             90             1971.0      25 - 50%
# 182             20                NaN      >0 - 25%
# 183             50                NaN            0%
# 184            NaN                NaN   75 - < 100%
# 185             30                NaN      >0 - 25%
# 186             20             1987.0            0%
# 187             41                NaN            0%
# 188              5             1971.0            0%
# 189              5             1962.0      >0 - 25%
# 190             15             1978.0      >0 - 25%
# 191             35                NaN      >0 - 25%
# 192             10                NaN            0%
# 193             40             1995.0      >0 - 25%
# 194            NaN                NaN      >0 - 25%
# 195            NaN                NaN  Not Assessed
# 196             10             1993.0  Not Assessed
# 197            NaN                NaN  Not Assessed
# 198             68                NaN  Not Assessed
# 199            NaN                NaN  Not Assessed
# 200             30             1969.0  Not Assessed
# 201             34             1987.0  Not Assessed
# 202              5                NaN  Not Assessed
# 203             51             1993.0  Not Assessed
# 204             17             1972.0  Not Assessed
# 205             25                NaN  Not Assessed
# 206             55             1994.0  Not Assessed
# 207             12             1993.0  Not Assessed
# 208              7                NaN  Not Assessed
# 209             15             1966.0  Not Assessed
# 210             30                NaN  Not Assessed
#
#     Tumor Location (choice=RUL) Tumor Location (choice=RML)  \
# 0                     Unchecked                   Unchecked
# 1                     Unchecked                   Unchecked
# 2                     Unchecked                   Unchecked
# 3                     Unchecked                   Unchecked
# 4                     Unchecked                   Unchecked
# 5                       Checked                   Unchecked
# 6                       Checked                   Unchecked
# 7                     Unchecked                   Unchecked
# 8                     Unchecked                   Unchecked
# 9                       Checked                   Unchecked
# 10                    Unchecked                   Unchecked
# 11                    Unchecked                   Unchecked
# 12                    Unchecked                   Unchecked
# 13                    Unchecked                   Unchecked
# 14                      Checked                   Unchecked
# 15                    Unchecked                   Unchecked
# 16                    Unchecked                   Unchecked
# 17                    Unchecked                   Unchecked
# 18                      Checked                   Unchecked
# 19                    Unchecked                   Unchecked
# 20                      Checked                   Unchecked
# 21                      Checked                   Unchecked
# 22                      Checked                   Unchecked
# 23                    Unchecked                   Unchecked
# 24                      Checked                   Unchecked
# 25                    Unchecked                   Unchecked
# 26                      Checked                   Unchecked
# 27                      Checked                   Unchecked
# 28                    Unchecked                   Unchecked
# 29                      Checked                   Unchecked
# 30                    Unchecked                     Checked
# 31                      Checked                   Unchecked
# 32                      Checked                   Unchecked
# 33                    Unchecked                   Unchecked
# 34                    Unchecked                     Checked
# 35                      Checked                   Unchecked
# 36                      Checked                   Unchecked
# 37                    Unchecked                   Unchecked
# 38                    Unchecked                   Unchecked
# 39                    Unchecked                   Unchecked
# 40                    Unchecked                   Unchecked
# 41                    Unchecked                   Unchecked
# 42                    Unchecked                   Unchecked
# 43                    Unchecked                   Unchecked
# 44                      Checked                   Unchecked
# 45                      Checked                   Unchecked
# 46                      Checked                   Unchecked
# 47                    Unchecked                   Unchecked
# 48                      Checked                   Unchecked
# 49                      Checked                   Unchecked
# 50                      Checked                   Unchecked
# 51                    Unchecked                   Unchecked
# 52                    Unchecked                   Unchecked
# 53                    Unchecked                     Checked
# 54                    Unchecked                   Unchecked
# 55                    Unchecked                   Unchecked
# 56                      Checked                   Unchecked
# 57                    Unchecked                     Checked
# 58                      Checked                   Unchecked
# 59                    Unchecked                   Unchecked
# 60                      Checked                   Unchecked
# 61                    Unchecked                   Unchecked
# 62                      Checked                   Unchecked
# 63                      Checked                   Unchecked
# 64                    Unchecked                   Unchecked
# 65                    Unchecked                   Unchecked
# 66                    Unchecked                   Unchecked
# 67                      Checked                   Unchecked
# 68                      Checked                   Unchecked
# 69                      Checked                   Unchecked
# 70                    Unchecked                   Unchecked
# 71                    Unchecked                   Unchecked
# 72                    Unchecked                   Unchecked
# 73                      Checked                   Unchecked
# 74                    Unchecked                   Unchecked
# 75                      Checked                   Unchecked
# 76                    Unchecked                   Unchecked
# 77                    Unchecked                   Unchecked
# 78                    Unchecked                   Unchecked
# 79                    Unchecked                   Unchecked
# 80                      Checked                   Unchecked
# 81                    Unchecked                   Unchecked
# 82                    Unchecked                   Unchecked
# 83                    Unchecked                   Unchecked
# ...
# 135           Alive           NaN                   NaN    5/7/1994
# 136           Alive           NaN                   NaN   5/24/1994
# 137           Alive           NaN                   NaN   6/18/1994
# 138            Dead     2/17/1996                 477.0  10/14/1994
# 139            Dead     10/9/1997                 985.0  11/26/1994
# 140            Dead    11/30/1996                 861.0    5/5/1994
# 141            Dead     11/3/1995                  47.0   6/22/1994
# 142           Alive           NaN                   NaN    9/7/1994
# 143           Alive           NaN                   NaN    8/4/1994
# 144           Alive           NaN                   NaN    7/5/1994
# 145            Dead    11/22/1998                1352.0   2/22/1995
# 146           Alive           NaN                   NaN  11/17/1994
# 147            Dead     4/26/1998                 952.0  12/21/1994
# 148            Dead     6/26/1997                 867.0    1/5/1995
# 149            Dead      4/7/1999                1491.0   2/28/1995
# 150           Alive           NaN                   NaN   2/14/1995
# 151            Dead     11/9/1995                 210.0   3/25/1995
rad_labels.loc[lambda rad_labels: rad_labels['Case ID'] == '%s' %(patients_labels[i][:(len(patients_labels[i]) -4)])]['Histology'].values[0] == 'Adenocarcinoma'):  #patient ID
        Hist_adenocarcinoma = Hist_adenocarcinoma.append(dataset[lambda dataset: dataset['Image'] == '%s'%patients_labels[i]])
    elif (rad_labels.loc[lambda rad_labels: rad_labels['Case ID'] == '%s' %(patients_labels[i][:(len(patients_labels[i]) -4)])]['Histology'].values[0] == 'Squamous cell carcinoma'):  #patient ID
        Hist_squamous = Hist_squamous.append(dataset[lambda dataset: dataset['Image'] == '%s'%patients_labels[i]])
        
    if (rad_labels.loc[lambda rad_labels: rad_labels['Case ID'] == '%s' %(patients_labels[i][:(len(patients_labels[i]) -4)])]['EGFR mutation status'].values[0] == 'Wildtype'):  #patient ID
        EGFR_wildtype = EGFR_wildtype.append(dataset[lambda dataset: dataset['Image'] == '%s'%patients_labels[i]])
    elif (rad_labels.loc[lambda rad_labels: rad_labels['Case ID'] == '%s' %(patients_labels[i][:(len(patients_labels[i]) -4)])]['EGFR mutation status'].values[0] == 'Mutant'):  #patient ID
        EGRF_mutant = EGRF_mutant.append(dataset[lambda dataset: dataset['Image'] == '%s'%patients_labels[i]])
    
    if (rad_labels.loc[lambda rad_labels: rad_labels['Case ID'] == '%s' %(patients_labels[i][:(len(patients_labels[i]) -4)])]['KRAS mutation status'].values[0] == 'Wildtype'):  #patient ID
        KRAS_wildtype = KRAS_wildtype.append(dataset[lambda dataset: dataset['Image'] == '%s'%patients_labels[i]])
    elif (rad_labels.loc[lambda rad_labels: rad_labels['Case ID'] == '%s' %(patients_labels[i][:(len(patients_labels[i]) -4)])]['KRAS mutation status'].values[0] == 'Mutant'):  #patient ID
        KRAS_mutant = KRAS_mutant.append(dataset[lambda dataset: dataset['Image'] == '%s'%patients_labels[i]])

# %%
neg = []
pos = []
for i in range(0,Hist_adenocarcinoma.shape[0]):
    pos.append(1)
for i in range(0,Hist_squamous.shape[0]):
    neg.append(0)

Hist_adenocarcinoma.insert(2,"Adenocarcinoma_status",pos, True)
Hist_squamous.insert(2,"Adenocarcinoma_status",neg, True)


neg = []
pos = []
for i in range(0,EGFR_wildtype.shape[0]):
    pos.append(1)
for i in range(0,EGRF_mutant.shape[0]):
    neg.append(0)

EGFR_wildtype.insert(2,"EGFR mutation status",pos, True)
EGRF_mutant.insert(2,"EGFR mutation status",neg, True)


neg = []
pos = []
for i in range(0,KRAS_wildtype.shape[0]):
    pos.append(1)
for i in range(0,KRAS_mutant.shape[0]):
    neg.append(0)

KRAS_wildtype.insert(2,"KRAS mutation status",pos, True)
KRAS_mutant.insert(2,"KRAS mutation status",neg, True)

# %%
data_Hist = Hist_adenocarcinoma.append(Hist_squamous)
data_Hist = data_Hist.drop([102]) #NaN
target_Hist = data_Hist['Adenocarcinoma_status'].tolist()
target_Hist_series = data_Hist['Adenocarcinoma_status']


num_data_Hist = data_Hist.iloc[:,3:]
num_array_Hist = num_data_Hist.to_numpy()
num_array_Hist = np.nan_to_num(num_array_Hist)
print(num_array_Hist.shape)
print(len(target_Hist))



data_EGFR = EGFR_wildtype.append(EGRF_mutant)
data_EGFR = data_EGFR.drop([102]) #NaN
target_EGFR = data_EGFR['EGFR mutation status'].tolist()
target_EGFR_series = data_EGFR['EGFR mutation status']

num_data_EGFR = data_EGFR.iloc[:,3:]
num_array_EGFR = num_data_EGFR.to_numpy()
num_array_EGFR = np.nan_to_num(num_array_EGFR)
print(num_array_EGFR.shape)
print(len(target_EGFR))



data_KRAS = KRAS_wildtype.append(KRAS_mutant)
data_KRAS = data_KRAS.drop([102]) #NaN
target_KRAS = data_KRAS['KRAS mutation status'].tolist()
target_KRAS_series = data_KRAS['KRAS mutation status']

num_data_KRAS = data_KRAS.iloc[:,3:]
num_array_KRAS = num_data_KRAS.to_numpy()
num_array_KRAS = np.nan_to_num(num_array_KRAS)
print(num_array_KRAS.shape)
print(len(target_KRAS))

#p.any(np.isnan(numerical_array))
#p.argwhere(np.isnan(numerical_array))
# Out:
# (138, 1562)
# 138
# (114, 1562)
# 114
# (112, 1562)
# 112

# %%
num_data_Hist = data_Hist.iloc[:,3:]
num = num_data_Hist

for i in range(0,num_data_Hist.shape[1]):
    if len(set(num_data_Hist.iloc[:,i])) <= 2 :
        num = num.drop(num_data_Hist.columns[i],1)
        
num_array_Hist = num.to_numpy()
num_array_Hist = np.nan_to_num(num_array_Hist)
print(num_array_Hist.shape)



num_data_EGFR = data_EGFR.iloc[:,3:]
num = num_data_EGFR

for i in range(0,num_data_EGFR.shape[1]):
    if len(set(num_data_EGFR.iloc[:,i])) <= 2 :
        num = num.drop(num_data_EGFR.columns[i],1)
        
num_array_EGFR = num.to_numpy()
num_array_EGFR = np.nan_to_num(num_array_EGFR)
print(num_array_EGFR.shape)



num_data_KRAS = data_KRAS.iloc[:,3:]
num = num_data_KRAS

for i in range(0,num_data_KRAS.shape[1]):
    if len(set(num_data_KRAS.iloc[:,i])) <= 2 :
        num = num.drop(num_data_KRAS.columns[i],1)
        
num_array_KRAS = num.to_numpy()
num_array_KRAS = np.nan_to_num(num_array_KRAS)
print(num_array_KRAS.shape)
# Out:
# (138, 1488)
# (114, 1488)
# (112, 1488)

# %%
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif


X,y = num_array_Hist, target_Hist #uncomment the desired label to examine
#X,y = num_array_EGFR, target_EGFR
#X,y = num_array_KRAS, target_KRAS
fvalue_selector = SelectKBest(f_classif, k=15)

X_kbest = fvalue_selector.fit_transform(X,y)

# Show results
print('Original number of features:', X.shape[1])
print('Reduced number of features:', X_kbest.shape[1])
# Out:
# Original number of features: 1488
# Reduced number of features: 15

# %%
final_features = []
for i in range(0,X_kbest.shape[1]):
    a = ((num_data_Hist.isin(X_kbest[:,i])).all()) #find where it is      #uncomment the desired label to examine
    #a = ((num_data_EGFR.isin(X_kbest[:,i])).all()) #find where it is
    #a = ((num_data_KRAS.isin(X_kbest[:,i])).all()) #find where it is
    final_features.append((a[a == True]).index.tolist())
final_features
# Out:
# [['original_firstorder_Median'],
#  ['original_glcm_Autocorrelation'],
#  ['original_glcm_ClusterShade'],
#  ['wavelet-LLH_firstorder_TotalEnergy'],
#  ['wavelet-HLH_firstorder_TotalEnergy'],
#  ['wavelet-LLL_glcm_Autocorrelation'],
#  ['wavelet-LLL_glcm_JointAverage'],
#  ['wavelet-LLL_glcm_ClusterShade'],
#  ['wavelet-LLL_glrlm_HighGrayLevelRunEmphasis'],
#  ['wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis'],
#  ['wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis'],
#  ['wavelet-LLL_gldm_HighGrayLevelEmphasis'],
#  ['log-sigma-1-mm-3D_glszm_SizeZoneNonUniformityNormalized'],
#  ['log-sigma-1-mm-3D_glszm_SmallAreaEmphasis'],
#  ['squareroot_glcm_ClusterShade']]

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif

high_acc = 0
fts = 0
for nnn in range(1,16):
    total_before = total_after = 0
    for iii in range(0,10):
        
        #X= num_array_Hist          #uncomment the desired label to examine
        #y = np.array(target_Hist)
        #X= num_array_EGFR
        #y = np.array(target_EGFR)
        X= num_array_KRAS
        y = np.array(target_KRAS)

        # Split dataset with test 0.35, train 0.65
        X_train, X_test, y_train, y_test = train_test_split(
                X, y, stratify=y, test_size = 0.35
        )

        #plt.figure(1)
        #plt.clf()

        X_indices = np.arange(X.shape[-1])


        # Univariate feature selection with F-test for feature scoring
        # We use the default selection function to select the four
        # most significant features
        selector = SelectKBest(f_classif, k=nnn)
        selector.fit(X_train, y_train)
        scores = -np.log10(selector.pvalues_)
        scores /= scores.max()

        # Compare to the weights of an SVM
        clf = make_pipeline(MinMaxScaler(), LinearSVC(max_iter = 100000))
        clf.fit(X_train, y_train)

        total_before = total_before + clf.score(X_test, y_test)

        svm_weights = np.abs(clf[-1].coef_).sum(axis=0)
        svm_weights /= svm_weights.sum()


        clf_selected = make_pipeline(
                SelectKBest(f_classif, k=nnn), MinMaxScaler(), LinearSVC(max_iter = 100000)
        )
        clf_selected.fit(X_train, y_train)

        total_after = total_after + clf_selected.score(X_test, y_test)

        svm_weights_selected = np.abs(clf_selected[-1].coef_).sum(axis=0)
        svm_weights_selected /= svm_weights_selected.sum()

    print('Number of selected features:', nnn)
    print('Classification accuracy without selecting features: {:.3f}'
         .format(total_before/(iii + 1)))

    print('Classification accuracy after univariate feature selection: {:.3f}'
        .format(total_after/(iii + 1)))
    
    if ((total_after/(iii+1)) > high_acc):
        high_acc = (total_after/(iii+1))
        fts = selector
# Out:
# Number of selected features: 1
# Classification accuracy without selecting features: 0.607
# Classification accuracy after univariate feature selection: 0.755
# Number of selected features: 2
# Classification accuracy without selecting features: 0.635
# Classification accuracy after univariate feature selection: 0.740
# Number of selected features: 3
# Classification accuracy without selecting features: 0.608
# Classification accuracy after univariate feature selection: 0.743
# Number of selected features: 4
# Classification accuracy without selecting features: 0.617
# Classification accuracy after univariate feature selection: 0.728
# Number of selected features: 5
# Classification accuracy without selecting features: 0.623
# Classification accuracy after univariate feature selection: 0.743
# Number of selected features: 6
# Classification accuracy without selecting features: 0.622
# Classification accuracy after univariate feature selection: 0.735
# Number of selected features: 7
# Classification accuracy without selecting features: 0.633
# Classification accuracy after univariate feature selection: 0.755
# Number of selected features: 8
# Classification accuracy without selecting features: 0.628
# Classification accuracy after univariate feature selection: 0.738
# Number of selected features: 9
# Classification accuracy without selecting features: 0.610
# Classification accuracy after univariate feature selection: 0.728
# Number of selected features: 10
# Classification accuracy without selecting features: 0.575
# Classification accuracy after univariate feature selection: 0.740
# Number of selected features: 11
# Classification accuracy without selecting features: 0.605
# Classification accuracy after univariate feature selection: 0.750
# Number of selected features: 12
# Classification accuracy without selecting features: 0.628
# Classification accuracy after univariate feature selection: 0.748
# Number of selected features: 13
# Classification accuracy without selecting features: 0.630
# Classification accuracy after univariate feature selection: 0.765
# Number of selected features: 14
# Classification accuracy without selecting features: 0.613
# Classification accuracy after univariate feature selection: 0.745
# Number of selected features: 15
# Classification accuracy without selecting features: 0.635
# Classification accuracy after univariate feature selection: 0.715

# %%
#Histology - 3 feats
num.columns[fts.get_support()].tolist()
# Out:
# ['original_glcm_ClusterShade',
#  'wavelet-LHL_firstorder_TotalEnergy',
#  'wavelet-LHH_firstorder_TotalEnergy']

# %%
#EGFR - 5 feats
num.columns[fts.get_support()].tolist()
# Out:
# ['wavelet-LHH_glrlm_LongRunLowGrayLevelEmphasis',
#  'wavelet-LHH_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'exponential_glszm_SizeZoneNonUniformityNormalized',
#  'lbp-3D-k_glcm_ClusterShade',
#  'lbp-3D-k_gldm_DependenceNonUniformityNormalized']

# %%
#KRAS - 13 feats
num.columns[fts.get_support()].tolist()
# Out:
# ['wavelet-HLH_firstorder_Mean',
#  'wavelet-HLH_glcm_Imc2',
#  'wavelet-HHL_firstorder_Mean',
#  'wavelet-HHH_glcm_Imc2',
#  'lbp-3D-k_firstorder_90Percentile',
#  'lbp-3D-k_firstorder_MeanAbsoluteDeviation',
#  'lbp-3D-k_firstorder_Variance',
#  'lbp-3D-k_glcm_Idn',
#  'lbp-3D-k_glcm_InverseVariance',
#  'lbp-3D-k_glcm_MaximumProbability',
#  'lbp-3D-k_glrlm_RunPercentage',
#  'lbp-3D-k_gldm_LargeDependenceEmphasis',
#  'lbp-3D-k_gldm_LargeDependenceLowGrayLevelEmphasis']

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import KFold

high_acc = 0
fts = 0
for nnn in range(1,16):
    total_before = total_after = 0
    
    #X= num_array_Hist          #uncomment the desired label to examine
    #y = np.array(target_Hist)
    #X= num_array_EGFR
    #y = np.array(target_EGFR)
    X= num_array_KRAS
    y = np.array(target_KRAS)

    n_splits = 5
    kfold = KFold(n_splits=5, random_state=None, shuffle=True)
    for train_index, test_index in kfold.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        X_indices = np.arange(X.shape[-1])


        # Univariate feature selection with F-test for feature scoring
        # We use the default selection function to select the four
        # most significant features
        selector = SelectKBest(f_classif, k=nnn)
        selector.fit(X_train, y_train)
        scores = -np.log10(selector.pvalues_)
        scores /= scores.max()

        # Compare to the weights of an SVM
        clf = make_pipeline(MinMaxScaler(), LinearSVC(max_iter = 100000))
        clf.fit(X_train, y_train)

        total_before = total_before + clf.score(X_test, y_test)

        svm_weights = np.abs(clf[-1].coef_).sum(axis=0)
        svm_weights /= svm_weights.sum()


        clf_selected = make_pipeline(
                SelectKBest(f_classif, k=nnn), MinMaxScaler(), LinearSVC(max_iter = 100000)
        )
        clf_selected.fit(X_train, y_train)

        total_after = total_after + clf_selected.score(X_test, y_test)

        svm_weights_selected = np.abs(clf_selected[-1].coef_).sum(axis=0)
        svm_weights_selected /= svm_weights_selected.sum()

    print('Number of selected features:', nnn)
    print('Classification accuracy without selecting features: {:.3f}'
         .format(total_before/n_splits))

    print('Classification accuracy after univariate feature selection: {:.3f}'
        .format(total_after/n_splits))
    
    if ((total_after/n_splits) > high_acc):
        high_acc = (total_after/n_splits)
        fts = selector
# Out:
# Number of selected features: 1
# Classification accuracy without selecting features: 0.671
# Classification accuracy after univariate feature selection: 0.750
# Number of selected features: 2
# Classification accuracy without selecting features: 0.616
# Classification accuracy after univariate feature selection: 0.750
# Number of selected features: 3
# Classification accuracy without selecting features: 0.616
# Classification accuracy after univariate feature selection: 0.713
# Number of selected features: 4
# Classification accuracy without selecting features: 0.570
# Classification accuracy after univariate feature selection: 0.741
# Number of selected features: 5
# Classification accuracy without selecting features: 0.579
# Classification accuracy after univariate feature selection: 0.767
# Number of selected features: 6
# Classification accuracy without selecting features: 0.526
# Classification accuracy after univariate feature selection: 0.758
# Number of selected features: 7
# Classification accuracy without selecting features: 0.581
# Classification accuracy after univariate feature selection: 0.732
# Number of selected features: 8
# Classification accuracy without selecting features: 0.634
# Classification accuracy after univariate feature selection: 0.740
# Number of selected features: 9
# Classification accuracy without selecting features: 0.626
# Classification accuracy after univariate feature selection: 0.689
# Number of selected features: 10
# Classification accuracy without selecting features: 0.562
# Classification accuracy after univariate feature selection: 0.724
# Number of selected features: 11
# Classification accuracy without selecting features: 0.598
# Classification accuracy after univariate feature selection: 0.749
# Number of selected features: 12
# Classification accuracy without selecting features: 0.572
# Classification accuracy after univariate feature selection: 0.750
# Number of selected features: 13
# Classification accuracy without selecting features: 0.590
# Classification accuracy after univariate feature selection: 0.768
# Number of selected features: 14
# Classification accuracy without selecting features: 0.589
# Classification accuracy after univariate feature selection: 0.742
# Number of selected features: 15
# Classification accuracy without selecting features: 0.570
# Classification accuracy after univariate feature selection: 0.733

# %%
#Histology - 3 feats
num.columns[fts.get_support()].tolist()
# Out:
# ['original_glcm_ClusterShade', 'wavelet-LLL_glcm_ClusterShade']

# %%
#EGFR - 4 feats
num.columns[fts.get_support()].tolist()
# Out:
# ['lbp-3D-k_glrlm_LongRunEmphasis',
#  'lbp-3D-k_glrlm_LongRunHighGrayLevelEmphasis',
#  'lbp-3D-k_glrlm_LongRunLowGrayLevelEmphasis',
#  'lbp-3D-k_glrlm_RunVariance']

# %%
#KRAS - 13 feats
num.columns[fts.get_support()].tolist()
# Out:
# ['original_glcm_ClusterProminence',
#  'original_glrlm_LowGrayLevelRunEmphasis',
#  'original_glrlm_ShortRunLowGrayLevelEmphasis',
#  'original_glszm_LowGrayLevelZoneEmphasis',
#  'original_glszm_SmallAreaLowGrayLevelEmphasis',
#  'original_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'log-sigma-1-mm-3D_glcm_ClusterProminence',
#  'log-sigma-1-mm-3D_glcm_DifferenceVariance',
#  'square_gldm_LowGrayLevelEmphasis',
#  'squareroot_glszm_LowGrayLevelZoneEmphasis',
#  'squareroot_glszm_SmallAreaLowGrayLevelEmphasis',
#  'squareroot_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'logarithm_gldm_SmallDependenceLowGrayLevelEmphasis']

# %%
'''X = num_data_Hist
y = target_Hist_series
data = X.append(y)

from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pandas.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='barh')
plt.show()
'''
# Out:
# "X = num_data_Hist\ny = target_Hist_series\ndata = X.append(y)\n\nfrom sklearn.ensemble import ExtraTreesClassifier\nimport matplotlib.pyplot as plt\nmodel = ExtraTreesClassifier()\nmodel.fit(X,y)\nprint(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers\n#plot graph of feature importances for better visualization\nfeat_importances = pandas.Series(model.feature_importances_, index=X.columns)\nfeat_importances.nlargest(15).plot(kind='barh')\nplt.show()\n"
