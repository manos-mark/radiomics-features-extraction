# %% [markdown]
# # 1. Data preparation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 1.1 Data set structure
#
# First step, I want to have an overview about my dataset. There are no missing values, but there is very high variance.

# %%
dataset = pd.read_csv('../../data/extracted-features/cli_results.csv')
dataset
# Out:
#         ID                                              Image  \
# 0   brain1  /home/manos/git/radiomics-features-extraction/...
# 1  breast1  /home/manos/git/radiomics-features-extraction/...
# 2   brain2  /home/manos/git/radiomics-features-extraction/...
# 3    lung1  /home/manos/git/radiomics-features-extraction/...
# 4    lung2  /home/manos/git/radiomics-features-extraction/...
#
#                                                 Mask  \
# 0  /home/manos/git/radiomics-features-extraction/...
# 1  /home/manos/git/radiomics-features-extraction/...
# 2  /home/manos/git/radiomics-features-extraction/...
# 3  /home/manos/git/radiomics-features-extraction/...
# 4  /home/manos/git/radiomics-features-extraction/...
#
#    original_shape_VoxelVolume  original_shape_MeshVolume  \
# 0                16412.658691               16147.511800
# 1                  132.425795                 124.091305
# 2                 1797.180176                1736.017863
# 3                 1361.197815                1330.976079
# 4                48434.108762               48292.521605
#
#    original_shape_SurfaceArea  original_shape_SurfaceVolumeRatio  \
# 0                 6438.821604                           0.398750
# 1                  172.887079                           1.393225
# 2                  929.760151                           0.535571
# 3                  782.241458                           0.587720
# 4                 9537.544880                           0.197495
#
#    original_shape_Sphericity  original_shape_Maximum3DDiameter  \
# 0                   0.479823                         69.600990
# 1                   0.695904                          9.081019
# 2                   0.751304                         24.444532
# 3                   0.748038                         21.344947
# 4                   0.672410                         68.982471
#
#    original_shape_Maximum2DDiameterSlice  ...  \
# 0                              53.593978  ...
# 1                               8.399794  ...
# 2                              16.312979  ...
# 3                              16.627324  ...
# 4                              55.802348  ...
#
#    lbp-3D-k_gldm_GrayLevelNonUniformity  lbp-3D-k_gldm_GrayLevelVariance  \
# 0                           3566.861252                         0.068907
# 1                            133.349650                         0.033742
# 2                            356.355408                         0.106672
# 3                            727.317802                         0.065521
# 4                          17119.980928                         0.152654
#
#    lbp-3D-k_gldm_HighGrayLevelEmphasis  lbp-3D-k_gldm_LargeDependenceEmphasis  \
# 0                             1.223350                             293.398356
# 1                             1.104895                             199.881119
# 2                             1.364238                             194.677704
# 3                             1.211470                             263.203106
# 4                             1.563991                             353.020938
#
#    lbp-3D-k_gldm_LargeDependenceHighGrayLevelEmphasis  \
# 0                                         298.803723
# 1                                         200.405594
# 2                                         206.988962
# 3                                         276.848268
# 4                                         404.116986
#
#    lbp-3D-k_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                         292.047015
# 1                                         199.750000
# 2                                         191.599890
# 3                                         259.791816
# 4                                         340.246926
#
#    lbp-3D-k_gldm_LowGrayLevelEmphasis  lbp-3D-k_gldm_SmallDependenceEmphasis  \
# 0                            0.944162                               0.020216
# 1                            0.973776                               0.015501
# 2                            0.908940                               0.017346
# 3                            0.947133                               0.007737
# 4                            0.859002                               0.009814
#
#    lbp-3D-k_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           0.062005
# 1                                           0.038811
# 2                                           0.049359
# 3                                           0.015102
# 4                                           0.029027
#
#    lbp-3D-k_gldm_SmallDependenceLowGrayLevelEmphasis
# 0                                           0.009769
# 1                                           0.009674
# 2                                           0.009343
# 3                                           0.005896
# 4                                           0.005011
#
# [5 rows x 1565 columns]

# %%
dataset.describe()
# Out:
#        original_shape_VoxelVolume  original_shape_MeshVolume  \
# count                    5.000000                   5.000000
# mean                 13627.514248               13526.223730
# std                  20565.704381               20511.684428
# min                    132.425795                 124.091305
# 25%                   1361.197815                1330.976079
# 50%                   1797.180176                1736.017863
# 75%                  16412.658691               16147.511800
# max                  48434.108762               48292.521605
#
#        original_shape_SurfaceArea  original_shape_SurfaceVolumeRatio  \
# count                    5.000000                           5.000000
# mean                  3572.251034                           0.622552
# std                   4187.019951                           0.456475
# min                    172.887079                           0.197495
# 25%                    782.241458                           0.398750
# 50%                    929.760151                           0.535571
# 75%                   6438.821604                           0.587720
# max                   9537.544880                           1.393225
#
#        original_shape_Sphericity  original_shape_Maximum3DDiameter  \
# count                   5.000000                          5.000000
# mean                    0.669496                         38.690792
# std                     0.111291                         28.520164
# min                     0.479823                          9.081019
# 25%                     0.672410                         21.344947
# 50%                     0.695904                         24.444532
# 75%                     0.748038                         68.982471
# max                     0.751304                         69.600990
#
#        original_shape_Maximum2DDiameterSlice  \
# count                               5.000000
# mean                               30.147284
# std                                22.666387
# min                                 8.399794
# 25%                                16.312979
# 50%                                16.627324
# 75%                                53.593978
# max                                55.802348
#
#        original_shape_Maximum2DDiameterColumn  \
# count                                5.000000
# mean                                33.012852
# std                                 23.740129
# min                                  7.121408
# 25%                                 19.555666
# 50%                                 23.593253
# 75%                                 49.490855
# max                                 65.303079
#
#        original_shape_Maximum2DDiameterRow  original_shape_MajorAxisLength  \
# count                             5.000000                        5.000000
# mean                             34.903805                       32.188857
# std                              26.984225                       24.808750
# min                               8.240911                        7.730961
# 25%                              17.557495                       17.374483
# 50%                              20.728928                       18.067154
# 75%                              62.102629                       55.774466
# max                              65.889060                       61.997220
#
#        ...  lbp-3D-k_gldm_GrayLevelNonUniformity  \
# count  ...                              5.000000
# mean   ...                           4380.773008
# std    ...                           7254.897448
# min    ...                            133.349650
# 25%    ...                            356.355408
# 50%    ...                            727.317802
# 75%    ...                           3566.861252
# max    ...                          17119.980928
#
#        lbp-3D-k_gldm_GrayLevelVariance  lbp-3D-k_gldm_HighGrayLevelEmphasis  \
# count                         5.000000                             5.000000
# mean                          0.085499                             1.293589
# std                           0.045583                             0.177053
# min                           0.033742                             1.104895
# 25%                           0.065521                             1.211470
# 50%                           0.068907                             1.223350
# 75%                           0.106672                             1.364238
# max                           0.152654                             1.563991
#
#        lbp-3D-k_gldm_LargeDependenceEmphasis  \
# count                               5.000000
# mean                              260.836245
# std                                66.438676
# min                               194.677704
# 25%                               199.881119
# 50%                               263.203106
# 75%                               293.398356
# max                               353.020938
#
#        lbp-3D-k_gldm_LargeDependenceHighGrayLevelEmphasis  \
# count                                           5.000000
# mean                                          277.432707
# std                                            82.766940
# min                                           200.405594
# 25%                                           206.988962
# 50%                                           276.848268
# 75%                                           298.803723
# max                                           404.116986
#
#        lbp-3D-k_gldm_LargeDependenceLowGrayLevelEmphasis  \
# count                                           5.000000
# mean                                          256.687129
# std                                            62.690481
# min                                           191.599890
# 25%                                           199.750000
# 50%                                           259.791816
# 75%                                           292.047015
# max                                           340.246926
#
#        lbp-3D-k_gldm_LowGrayLevelEmphasis  \
# count                            5.000000
# mean                             0.926603
# std                              0.044263
# min                              0.859002
# 25%                              0.908940
# 50%                              0.944162
# 75%                              0.947133
# max                              0.973776
#
#        lbp-3D-k_gldm_SmallDependenceEmphasis  \
# count                               5.000000
# mean                                0.014123
# std                                 0.005214
# min                                 0.007737
# 25%                                 0.009814
# 50%                                 0.015501
# 75%                                 0.017346
# max                                 0.020216
#
#        lbp-3D-k_gldm_SmallDependenceHighGrayLevelEmphasis  \
# count                                           5.000000
# mean                                            0.038861
# std                                             0.018076
# min                                             0.015102
# 25%                                             0.029027
# 50%                                             0.038811
# 75%                                             0.049359
# max                                             0.062005
#
#        lbp-3D-k_gldm_SmallDependenceLowGrayLevelEmphasis
# count                                           5.000000
# mean                                            0.007939
# std                                             0.002295
# min                                             0.005011
# 25%                                             0.005896
# 50%                                             0.009343
# 75%                                             0.009674
# max                                             0.009769
#
# [8 rows x 1562 columns]

# %% [markdown]
# ## 1.2 Clean dataset
#
# Remove the unnecessary columns and scale the rest.

# %%
dataset.drop(axis=1, labels=['ID', 'Mask', 'Image'], inplace=True)

# %%
columns = dataset.columns

scaled_dataset = pd.DataFrame(StandardScaler().fit_transform(dataset), columns=columns)
scaled_dataset
# Out:
#    original_shape_VoxelVolume  original_shape_MeshVolume  \
# 0                    0.151412                   0.142879
# 1                   -0.733647                  -0.730512
# 2                   -0.643144                  -0.642651
# 3                   -0.666846                  -0.664729
# 4                    1.892226                   1.895013
#
#    original_shape_SurfaceArea  original_shape_SurfaceVolumeRatio  \
# 0                    0.765443                          -0.548154
# 1                   -0.907711                           1.887593
# 2                   -0.705608                          -0.213042
# 3                   -0.744999                          -0.085313
# 4                    1.592875                          -1.041083
#
#    original_shape_Sphericity  original_shape_Maximum3DDiameter  \
# 0                  -1.905453                          1.211727
# 1                   0.265294                         -1.160748
# 2                   0.821851                         -0.558475
# 3                   0.789033                         -0.679984
# 4                   0.029275                          1.187480
#
#    original_shape_Maximum2DDiameterSlice  \
# 0                               1.156523
# 1                              -1.072709
# 2                              -0.682386
# 3                              -0.666881
# 4                               1.265452
#
#    original_shape_Maximum2DDiameterColumn  \
# 0                                0.776026
# 1                               -1.219350
# 2                               -0.443613
# 3                               -0.633762
# 4                                1.520698
#
#    original_shape_Maximum2DDiameterRow  original_shape_MajorAxisLength  ...  \
# 0                             1.283808                        1.343347  ...
# 1                            -1.104720                       -1.102222  ...
# 2                            -0.587306                       -0.636410  ...
# 3                            -0.718707                       -0.667626  ...
# 4                             1.126925                        1.062912  ...
#
#    lbp-3D-k_gldm_GrayLevelNonUniformity  lbp-3D-k_gldm_GrayLevelVariance  \
# 0                             -0.125430                        -0.406961
# 1                             -0.654560                        -1.269462
# 2                             -0.620193                         0.519304
# 3                             -0.563025                        -0.490017
# 4                              1.963207                         1.647135
#
#    lbp-3D-k_gldm_HighGrayLevelEmphasis  lbp-3D-k_gldm_LargeDependenceEmphasis  \
# 0                            -0.443535                               0.547957
# 1                            -1.191541                              -1.025756
# 2                             0.446129                              -1.113320
# 3                            -0.518558                               0.039830
# 4                             1.707505                               1.551289
#
#    lbp-3D-k_gldm_LargeDependenceHighGrayLevelEmphasis  \
# 0                                           0.288684
# 1                                          -1.040499
# 2                                          -0.951570
# 3                                          -0.007895
# 4                                           1.711279
#
#    lbp-3D-k_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                           0.630615
# 1                                          -1.015428
# 2                                          -1.160778
# 3                                           0.055370
# 4                                           1.490221
#
#    lbp-3D-k_gldm_LowGrayLevelEmphasis  lbp-3D-k_gldm_SmallDependenceEmphasis  \
# 0                            0.443535                               1.306427
# 1                            1.191541                               0.295481
# 2                           -0.446129                               0.691163
# 3                            0.518558                              -1.369188
# 4                           -1.707505                              -0.923882
#
#    lbp-3D-k_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           1.431453
# 1                                          -0.003068
# 2                                           0.649327
# 3                                          -1.469473
# 4                                          -0.608240
#
#    lbp-3D-k_gldm_SmallDependenceLowGrayLevelEmphasis
# 0                                           0.891441
# 1                                           0.845102
# 2                                           0.684217
# 3                                          -0.994806
# 4                                          -1.425954
#
# [5 rows x 1562 columns]

# %% [markdown]
# # 2. Feature selection
#
# Perform multiple techiques of feature selection in order to compare them.

# %% [markdown]
# ## 2.1 PCA
#
# Perform PCA using the scaled dataset, while preserving 99% of the training set's variance.

# %%
pca = PCA(n_components=0.99)
reduced_dataset = pca.fit_transform(scaled_dataset)
reduced_dataset = pd.DataFrame(reduced_dataset)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.40058986, 0.35019616, 0.16340625, 0.08580773])

# %%
reduced_dataset
# Out:
#            0          1          2          3
# 0 -25.750887 -19.302559  -9.078808 -15.323076
# 1  45.881899 -12.302815  -5.599445  -2.632927
# 2 -13.999970 -17.554078  -2.982042  19.729584
# 3  -2.245882   7.719390  30.495355  -2.718362
# 4  -3.885160  41.440062 -12.835061   0.944781

# %%
def scree_plot(pca):
    '''
    Creates a scree plot associated with the principal components
    
    INPUT: pca = the instance of PCA in scikit learn
    
    OUTPUT: None
    '''
    
    num_components = len(pca.explained_variance_ratio_)
    ind = np.arange(num_components)
    vals = pca.explained_variance_ratio_
    
    plt.figure(figsize=(10, 6))
    ax = plt.subplot(111)
    cumvals = np.cumsum(vals)
    ax.bar(ind, vals)
    ax.plot(ind, cumvals)
    
    for i in range(num_components):
        ax.annotate(r"%s%%" % ((str(vals[i]*100)[:4])), (ind[i]+0.2, vals[i]), va="bottom", ha="center", fontsize=12)
        
    ax.xaxis.set_tick_params(width=0)
    ax.yaxis.set_tick_params(width=2, length=12)
    
    ax.set_xlabel("Principal Component")
    ax.set_ylabel("Variance Explained (%)")
    plt.title('Explained Variance Per Principal Component')
    
scree_plot(pca)

# %%
from sklearn import manifold
from sklearn.metrics import euclidean_distances
from sklearn.decomposition import PCA

similarities = euclidean_distances(dataset)


seed = np.random.RandomState(seed=3)

mds = manifold.MDS(n_components=2, max_iter=5000, eps=1e-12, random_state=seed,
                   n_init=10,
                   dissimilarity="precomputed", n_jobs=1, metric=False)
pos = mds.fit_transform(similarities)

# %%
import pandas as pd
import seaborn as sns

# Construct a pandas dataframe from the samples
d = pd.DataFrame(data=dataset, columns=dataset.columns)
corr = d.corr()

# Set up the matplotlib figure, make it big!
f, ax = plt.subplots(figsize=(15, 10))

# Draw the heatmap using seaborn
sns.heatmap(corr, vmax=.8, square=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-0413209e1b8f> in <module>
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#       3
#       4 # Construct a pandas dataframe from the samples
#       5 d = pd.DataFrame(data=dataset, columns=dataset.columns)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Choose a subset of features for clustering
dd = d.iloc[:,1:50]

pp = sns.clustermap(dd.corr(), linewidths=.5, figsize=(13,13))
_ = plt.setp(pp.ax_heatmap.get_yticklabels(), rotation=0)

plt.show()
