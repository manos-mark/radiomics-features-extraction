# %% [markdown]
# # Import data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import os

# %%
path = os.path.join('/home','manos','git','radiomics-features-extraction')
dataset = pd.read_excel(os.path.join(path, 'LifeX','data','lifex_extracted_features.xlsx'), skiprows=2)

# %%
selected_features = pd.read_excel(os.path.join(path,'info','info.xlsx'), usecols='C')
selected_features = selected_features.dropna().values.flatten()

# %%
dataset
# Out:
#     INFO_PatientName  INFO_PatientID      INFO_ProcessDateOfTexture  \
# 0            R01-001               0  Mon Aug 31 22:01:00 EEST 2020
# 1            R01-002               0  Mon Aug 31 22:01:04 EEST 2020
# 2            R01-003               0  Mon Aug 31 22:01:07 EEST 2020
# 3            R01-004               0  Mon Aug 31 22:01:11 EEST 2020
# 4            R01-005               0  Mon Aug 31 22:01:17 EEST 2020
# ..               ...             ...                            ...
# 136          R01-141               0  Tue Sep 01 00:17:51 EEST 2020
# 137          R01-142               0  Tue Sep 01 00:17:58 EEST 2020
# 138          R01-144               0  Tue Sep 01 00:18:02 EEST 2020
# 139          R01-145               0  Tue Sep 01 00:18:18 EEST 2020
# 140          R01-146               0  Tue Sep 01 00:25:48 EEST 2020
#
#     INFO_SeriesDate INFO_Series INFO_ActualFrameDuration INFO_NameOfRoi  \
# 0        01/01/9999         _OT          0.016666668 min   'R01-001_roi
# 1        01/01/9999         _OT          0.016666668 min   'R01-002_roi
# 2        01/01/9999         _OT          0.016666668 min   'R01-003_roi
# 3        01/01/9999         _OT          0.016666668 min   'R01-004_roi
# 4        01/01/9999         _OT          0.016666668 min   'R01-005_roi
# ..              ...         ...                      ...            ...
# 136      01/01/9999         _OT          0.016666668 min   'R01-141_roi
# 137      01/01/9999         _OT          0.016666668 min   'R01-142_roi
# 138      01/01/9999         _OT          0.016666668 min   'R01-144_roi
# 139      01/01/9999         _OT          0.016666668 min   'R01-145_roi
# 140      01/01/9999         _OT          0.016666668 min   'R01-146_roi
#
#      CONVENTIONAL_min   CONVENTIONAL_mean  CONVENTIONAL_std  ...  \
# 0                  212         885.128319        193.894371  ...
# 1                  197         923.300763        168.789315  ...
# 2                  209         981.034743        172.292246  ...
# 3                    0         949.320621        254.065288  ...
# 4                  241         998.108571        107.580219  ...
# ..                 ...                ...               ...  ...
# 136                  0         697.024302        376.269703  ...
# 137                  1         747.460890        306.082481  ...
# 138                  0         566.902259        339.750647  ...
# 139                  0         764.257596        366.614779  ...
# 140                 79         938.548393        253.225130  ...
#
#         GLZLM_LZE  GLZLM_LGZE  GLZLM_HGZE  GLZLM_SZLGE  GLZLM_SZHGE  \
# 0    2.480399e+05    0.005118  211.310345     0.004751   190.456898
# 1    2.549847e+05    0.005514  208.352941     0.005310   191.352945
# 2    2.168120e+05    0.005354  215.750000     0.004921   179.625021
# 3    2.916204e+04    0.022803  148.534247     0.022167   126.631661
# 4    3.067683e+07    0.004890  218.222222     0.004080   169.777778
# ..            ...         ...         ...          ...          ...
# 136  3.825003e+04    0.070451  110.161320     0.049795    85.221831
# 137  1.519399e+05    0.015698  146.693086     0.013542   108.628971
# 138  9.818609e+03    0.032343  128.068039     0.027741    92.302525
# 139  2.737522e+05    0.022552  122.238547     0.016302    85.803334
# 140  7.920089e+04    0.005831  192.999453     0.003168   103.254898
#
#        GLZLM_LZLGE   GLZLM_LZHGE  GLZLM_GLNU   GLZLM_ZLNU  GLZLM_ZP
# 0       858.271587  7.168345e+07    6.379310    23.482759  0.010693
# 1       882.302074  7.369050e+07    3.941176    15.117647  0.008103
# 2       750.216427  6.265859e+07    2.500000     6.250000  0.006042
# 3       100.927685  8.427608e+06    7.739726    54.917808  0.047188
# 4    106148.201516  8.865604e+09    1.888889     5.666667  0.000541
# ..             ...           ...         ...          ...       ...
# 136     134.079501  1.105316e+07  142.271037  1166.764761  0.172522
# 137     525.767517  4.391015e+07  211.636594  1282.714165  0.104766
# 138      34.181870  2.836833e+06  131.720412   878.650086  0.248473
# 139     947.358157  7.911301e+07  563.291732  3400.891259  0.126190
# 140     274.151633  2.288452e+07  586.583812  1000.785617  0.015194
#
# [141 rows x 93 columns]

# %%
selected_dataset = dataset[selected_features]
selected_dataset
# Out:
#      SHAPE_Volume(mL)  SHAPE_Sphericity[onlyFor3DROI])  \
# 0            0.814867                         0.623133
# 1            1.058429                         0.675971
# 2            0.727295                         0.664031
# 3            0.663074                         0.526423
# 4            4.448272                         0.637878
# ..                ...                              ...
# 136          3.852493                         0.484366
# 137          7.429909                         0.429556
# 138         20.736049                         0.559227
# 139         15.346029                         0.427587
# 140        594.977234                         0.391128
#
#      SHAPE_Surface(mm2)[onlyFor3DROI]  CONVENTIONAL_Skewness  \
# 0                          677.060395              -0.993208
# 1                          743.014522              -1.506179
# 2                          588.983431              -1.473731
# 3                          698.539523              -1.398342
# 4                         2050.567754              -2.519894
# ..                                ...                    ...
# 136                       2453.605978              -0.218895
# 137                       4286.674333              -0.275770
# 138                       6526.997886               0.405740
# 139                       6984.310503              -0.479984
# 140                      87464.556811              -1.274637
#
#      CONVENTIONAL_min   CONVENTIONAL_mean  CONVENTIONAL_std  CONVENTIONAL_max  \
# 0                  212         885.128319        193.894371              1178
# 1                  197         923.300763        168.789315              1168
# 2                  209         981.034743        172.292246              1314
# 3                    0         949.320621        254.065288              1390
# 4                  241         998.108571        107.580219              1415
# ..                 ...                ...               ...               ...
# 136                  0         697.024302        376.269703              1851
# 137                  1         747.460890        306.082481              1491
# 138                  0         566.902259        339.750647              1519
# 139                  0         764.257596        366.614779              2435
# 140                 79         938.548393        253.225130              2035
#
#      CONVENTIONAL_Kurtosis  GLCM_Correlation  ...   GLRLM_LRE  GLRLM_LGRE  \
# 0                 2.969218          0.129625  ...   50.676322    0.003566
# 1                 4.583928          0.055618  ...   51.573143    0.003560
# 2                 4.758523         -0.001720  ...   42.346656    0.003523
# 3                 4.179931          0.121874  ...   23.729861    0.006899
# 4                10.191594          0.037831  ...  206.724235    0.003470
# ..                     ...               ...  ...         ...         ...
# 136               1.741596          0.425132  ...   18.600899    0.068805
# 137               1.921768          0.357372  ...   43.901474    0.008859
# 138               1.805940          0.349759  ...    8.820161    0.022301
# 139               1.696016          0.540607  ...   47.214200    0.016052
# 140               3.435426          0.659313  ...  329.902059    0.004524
#
#      GLRLM_HGRE  GLRLM_SRLGE  GLRLM_SRHGE  GLRLM_LRLGE   GLRLM_LRHGE  \
# 0    283.977714     0.001059    74.674702     0.175458  14640.343453
# 1    285.099641     0.000897    62.743619     0.178553  14900.737881
# 2    286.586829     0.000777    57.290671     0.146591  12235.770344
# 3    261.364072     0.004875    93.088372     0.085571   6829.219496
# 4    288.503060     0.000538    43.592206     0.715319  59742.780258
# ..          ...          ...          ...          ...           ...
# 136  168.224702     0.063041   100.026374     0.154476   5236.851780
# 137  214.200807     0.007721   126.275542     0.157577  12605.612841
# 138  176.619214     0.021046   127.625829     0.052118   2422.969754
# 139  169.381083     0.014855   112.973790     0.177994  13505.675514
# 140  243.799503     0.002928   120.926217     1.143000  95279.125581
#
#       GLRLM_GLNU    GLRLM_RLNU  GLRLM_RP
# 0     443.824114     60.688086  0.184820
# 1     337.608366     41.408768  0.175735
# 2     250.664642     32.935118  0.199686
# 3     283.781768     86.537222  0.282482
# 4    1585.453190    105.656269  0.096435
# ..           ...           ...       ...
# 136   770.133165   2682.293079  0.402754
# 137  1603.722297   2925.910726  0.288259
# 138   517.981598   2511.358561  0.558974
# 139  2462.184634  11599.893356  0.324646
# 140  8401.620274   7648.148846  0.105999
#
# [141 rows x 29 columns]

# %%
selected_dataset.describe()
# Out:
#        SHAPE_Volume(mL)  SHAPE_Sphericity[onlyFor3DROI])  \
# count        141.000000                       141.000000
# mean          61.192500                         0.506114
# std          196.465279                         0.114687
# min            0.288391                         0.283915
# 25%            2.738155                         0.418717
# 50%            9.014893                         0.497387
# 75%           31.134679                         0.585390
# max         1487.425781                         0.822278
#
#        SHAPE_Surface(mm2)[onlyFor3DROI]  CONVENTIONAL_Skewness  \
# count                        141.000000             141.000000
# mean                       10835.065570              -0.467776
# std                        19960.247934               0.935330
# min                          300.570549              -3.503489
# 25%                         1870.232366              -0.976202
# 50%                         4266.695737              -0.304244
# 75%                         9554.243401               0.121995
# max                       152198.367140               1.291258
#
#        CONVENTIONAL_min   CONVENTIONAL_mean  CONVENTIONAL_std  \
# count         141.000000         141.000000        141.000000
# mean           37.893617         734.578678        295.992400
# std            69.215678         171.394547         76.455781
# min             0.000000         359.873363         97.826163
# 25%             0.000000         600.959626        250.110358
# 50%             0.000000         732.775343        304.878589
# 75%            42.000000         864.472926        349.070194
# max           313.000000        1034.103754        463.618233
#
#        CONVENTIONAL_max  CONVENTIONAL_Kurtosis  GLCM_Correlation  ...  \
# count        141.000000             141.000000        141.000000  ...
# mean        1588.007092               3.225150          0.392367  ...
# std          513.835903               2.788356          0.167442  ...
# min          871.000000               1.281472         -0.001720  ...
# 25%         1255.000000               1.733753          0.305671  ...
# 50%         1460.000000               2.134693          0.378646  ...
# 75%         1721.000000               3.255631          0.504158  ...
# max         3774.000000              18.244123          0.810396  ...
#
#         GLRLM_LRE  GLRLM_LGRE  GLRLM_HGRE  GLRLM_SRLGE  GLRLM_SRHGE  \
# count  141.000000  141.000000  141.000000   141.000000   141.000000
# mean    70.868811    0.034648  203.052402     0.030622   104.198086
# std    135.174900    0.038630   42.694168     0.034388    23.069568
# min      3.745382    0.003465  104.324987     0.000440    36.037345
# 25%     14.529990    0.006546  171.895637     0.005201    91.781602
# 50%     23.729861    0.018250  195.951728     0.016111   106.948396
# 75%     55.340040    0.050215  234.919691     0.046564   119.853693
# max    898.320109    0.167623  288.666873     0.146265   172.327401
#
#        GLRLM_LRLGE    GLRLM_LRHGE    GLRLM_GLNU    GLRLM_RLNU    GLRLM_RP
# count   141.000000     141.000000    141.000000    141.000000  141.000000
# mean      0.292931   20376.885110   1849.839147   4656.746331    0.350334
# std       0.462793   39087.302767   2601.702621   8699.882282    0.158098
# min       0.021195     894.306178     58.030773     30.646800    0.051111
# 25%       0.084507    4066.969291    352.410043    440.696720    0.224713
# 50%       0.154056    6748.629062    770.133165   1558.570884    0.353689
# 75%       0.264971   15941.668056   2067.453103   6348.639661    0.459483
# max       3.109625  259571.808128  16497.411154  69457.707883    0.722412
#
# [8 rows x 29 columns]

# %% [markdown]
# # Plot features as a heatmap
#
# A heat map gives the correlation of features to each other, red indicating positive correlation, and blue negative.  A heatmap may be clustered to show groupings of features that are similar.

# %%
import seaborn as sns

corr = selected_dataset.corr()

# Set up the matplotlib figure, make it big!
f, ax = plt.subplots(figsize=(15, 10))

# Draw the heatmap using seaborn
sns.heatmap(corr, vmax=.8, square=True)

# %% [markdown]
# # Cluster the heatmap
#
# Though useful, heatmaps tell a much better story if the features are clustered.  Here we take a smaller subset of the features and cluster.  In the [dendrogram](https://en.wikipedia.org/wiki/Dendrogram), there are 2 major groups, and many smaller groupings based on features.

# %%
# Choose a subset of features for clustering
dd = selected_dataset.iloc[:,1:50]

pp = sns.clustermap(dd.corr(), linewidths=.5, figsize=(13,13))
_ = plt.setp(pp.ax_heatmap.get_yticklabels(), rotation=0)

plt.show()

# %% [markdown]
# # Distributions

# %%
ax = selected_dataset.hist(alpha=0.5, figsize=(20,15))

# %%
# ax = selected_dataset.plot.kde()
